# %% [markdown]
# # Машинное обучение, MDS
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Групповой проект. Machine Learning

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 30.05.2026
#
# __Дедлайн по записи в таблицу:__ 4:00 05.06.2026
#
# __Дедлайн по загрузке работ:__ 4:00 17.06.2026
#
# __Защита проекта:__ ~ 18.06.2026 — 19.06.2026

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняемому ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой в обязательном порядке проверяется и учитывается в оценке вклад **каждого участника** в общую работу команды. Вследствие этого крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости команда большинством голосов имеет право исключить человека из команды **до загрузки работ** в Google форму (будет опубликована в чате позднее), сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1M2OpQfRmX8nVQPZcxBFpf_fVxIFl31RXx22BFXMj054/edit?usp=sharing

# %% [markdown]
# ## Отправка материалов группового проекта

# %% [markdown]
# Во избежание использования при выполнении группового проекта генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации (например, для автоматической генерации кода), **одному из участников команды** необходимо предварительно загрузить работу в форму. Наличие сгенерированного кода или любого другого случая "несанкционированного" использования нейросетей будет считаться плагиатом, и такой проект будет оценен в 0 баллов для всех участников. При отсутствии своевременно загруженных файлов с проектом команде также выставляется 0 за проект.
#
# *Примечание: презентацию проекта загружать необязательно, важно отправить содержательные файлы с кодом и ссылку на репозиторий GitHub (при наличии).*

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(29052026)`.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции.

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современной бизнес-индустрии использование машинного обучения и искусственного интеллекта приобретает критическое значение. Компании, стремящиеся оставаться конкурентоспособными, активно внедряют данные технологии для анализа данных, автоматизации процессов и прогнозирования тенденций. Это позволяет бизнесу в целом принимать более обоснованные решения, а также стараться оперативно реагировать на изменения рынка.
#
# В данном проекте вы на реальных данных попрактикуетесь в том, как осуществляется построение предсказательных моделей машинного обучения, как впоследствии эти модели применяются, а также в том, как происходит поиск скрытых закономерностей и полезных инсайтов, которые в дальнейшем помогают компаниям оптимизировать свои бизнес-процессы.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже вашему вниманию предлагаются примерные этапы реализации проекта:
#
# - Выбор компании и/или платформы;
# - Формулировка двух связанных бизнес-задач, которые могла бы хотеть решить компания/платформа на основе данных, используя современные методы классического машинного обучения;
# - Обоснование сформулированных бизнес-задач и описание того, как предлагаемое решение вписывается в бизнес-процессы компании;
# - Получение необходимых данных путём поиска открытых источников/датасетов, парсинга/работы с API;
# - Формулировка задач в терминах машинного обучения, для решения поставленных бизнес-задач;
# - Выбор и обоснование возможного пула методов и алгоритмов для решения сформулированных задач машинного обучения;
# - Первичная обработка данных;
# - Применение методов машинного обучения для решения поставленных задач;
# - Получение и агрегация результатов, финальные выводы.

# %% [markdown]
# ### Требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию и защитить ее перед комиссией.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных с платформы; дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных; и главное, безусловно, — дата-саентистов: реализовать поставленные задачи с помощью методов машинного обучения и извлечь полезные инсайты из проделанной работы. А в конце, конечно, — презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект исходя из того, что ваша цель — представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10-балльной шкале, исходя из 5 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задач и бизнес-обоснование (до 3 баллов)
#
# Данный критерий оценивает, насколько обоснованными, осмысленными и **содержательно связанными** получились две решаемые в проекте бизнес-задачи; насколько полно был осуществлён переход от бизнес-задач к задачам машинного обучения (насколько в реальности постановка задач соответствует исходной постановке задачи с точки зрения интересов компании); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.
#
# *По данному критерию можно получить **3 балла** только при условии, что в презентации представлена схема, иллюстрирующая, как предлагаемое решение вписывается в бизнес-процессы компании: откуда поступают данные, каким образом они обрабатываются, как модель генерирует предсказания и в каком формате эти предсказания используются для принятия бизнес-решений. Строгая нотация не обязательна — важна логика и понятность схемы для стороннего наблюдателя.*

# %% [markdown]
# ### Критерий 2. Инструменты извлечения и обработки данных (до 2 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных ручным и автоматизированным образом, использованные средства предобработки, подготовки данных и EDA. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.

# %% [markdown]
# ### Критерий 3. Инструменты машинного обучения (до 5 баллов)
#
# Данный критерий оценивает применение методов машинного обучения в проекте. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным. Кроме того, будет оценен сравнительный анализ моделей, использованных в решении.
#
# *__Важно:__ в случае **оценки меньше 1 балла** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **2 балла** только при условии осмысленного использования в проекте, помимо моделей машинного обучения, минимум трех объектов Transformer различной природы (Scaler'ы, алгоритмы снижения размерностей и прочее).*
#
# *По данному критерию можно получить **3 балла** только при условии осуществления сравнительного анализа эффективности различных моделей машинного обучения внутри вашего проекта на одних и тех же данных. Самих моделей машинного обучения должно быть не менее 5; их природа должна отличаться (например, деревья и случайный лес — это алгоритмы разной природы, а вот модели CatBoost и LightGBM — нет); их использование, как и настройка гиперпараметров, должны быть подробно описаны и обоснованы. Кроме того, в рамках сравнительного анализа должны быть получены и сформулированы явные, значимые выводы о сравнительной эффективности того или иного алгоритма.*
#
# *По данному критерию можно получить **4 балла** только при условии корректного и обоснованного применения в проекте двух инструментов/подходов/библиотек, не рассматривавшихся на соответствующих семинарах и лекциях.*
#
# *По данному критерию можно получить **5 баллов** только при условии, что как минимум одна модель внутри сравнительного анализа представляет собой нейронную сеть (для решения задачи классического машинного обучения).*

# %% [markdown]
# ### Загрузка исходного файла

# %% [markdown]
# Часть обработки датасеты вынесена в отедльную функцию.

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd

raw_data = pd.read_csv("ecommerce_customer_churn_dataset.csv", encoding='UTF-8', sep=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 raw_data = pd.read_csv("ecommerce_customer_churn_dataset.csv", encoding='UTF-8', sep=',')
#
# File c:\ML_GROUP\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\ML_GROUP\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\ML_GROUP\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\ML_GROUP\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\ML_GROUP\.venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ecommerce_customer_churn_dataset.csv'

# %%
raw_data.head()
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
# 3  56.0  Female     USA    New York               2.6             10.0
# 4  35.0    Male   India       Delhi               3.1             29.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
# 4                  51.4                NaN                   19.1
#
#    Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0             3.0  ...             17.9                     9.0
# 1             1.0  ...             42.8                     7.0
# 2             1.0  ...              0.0                     4.0
# 3             9.0  ...             41.4                     2.0
# 4             9.0  ...             37.9                     1.0
#
#    Product_Reviews_Written  Social_Media_Engagement_Score  Mobile_App_Usage  \
# 0                      4.0                           16.3              20.8
# 1                      3.0                            NaN              23.3
# 2                      1.0                            NaN               8.8
# 3                      5.0                           85.9              31.0
# 4                     11.0                           83.0              50.4
#
#    Payment_Method_Diversity  Lifetime_Value  Credit_Balance  Churned  \
# 0                       1.0          953.33          2278.0        0
# 1                       3.0         1067.47          3028.0        0
# 2                       NaN         1289.75          2317.0        0
# 3                       3.0         2340.92          2674.0        0
# 4                       4.0         3041.29          5354.0        0
#
#    Signup_Quarter
# 0              Q1
# 1              Q4
# 2              Q4
# 3              Q1
# 4              Q4
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Описание признаков датасета

# %% [markdown]
# | Признак | Описание |
# |--------|----------|
# | **Age** | Возраст пользователя |
# | **Gender** | Пол  |
# | **Country** | Страна |
# | **City** | Город |
# | **Membership_Years** | Стаж клиента |
# | **Login_Frequency** | Частота входов на сайт |
# | **Session_Duration_Avg** | Средняя длительность сессии на сайте |
# | **Pages_Per_Session** | Число страниц, просмотренных за сессию |
# | **Cart_Abandonment_Rate** | Доля брошенных корзин |
# | **Wishlist_Items** | Число товаров в избранном |
# | **Email_Open_Rate** | Доля открытия почты |
# | **Mobile_App_Usage** | Использование мобильного приложения |
# | **Social_Media_Engagement_Score** | Уровень вовлечения через соцсети |
# | **Total_Purchases** | Число покупок |
# | **Average_Order_Value** | Средний чек при покупке |
# | **Days_Since_Last_Purchase** | Давность последней покупки |
# | **Discount_Usage_Rate** | Доля заказов со скидкой |
# | **Return_Rate** | Доля возвратов |
# | **Payment_Method_Diversity** | Число способов оплаты |
# | **Customer_Service_Calls** | Звонки в поддержку |
# | **Product_Reviews_Written** | Число написанных отзывов |
# | **Lifetime_Value** | Выручка |
# | **Credit_Balance** | Баланс клиента |
# | **Signup_Quarter** | Квартал регистрации |
# | **Churned** | Ушел ли клиент? |

# %% [markdown]
# ### Обработка датасета

# %%
raw_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
raw_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            47505 non-null  float64
#  1   Gender                         50000 non-null  str
#  2   Country                        50000 non-null  str
#  3   City                           50000 non-null  str
#  4   Membership_Years               50000 non-null  float64
#  5   Login_Frequency                50000 non-null  float64
#  6   Session_Duration_Avg           46601 non-null  float64
#  7   Pages_Per_Session              47000 non-null  float64
#  8   Cart_Abandonment_Rate          50000 non-null  float64
#  9   Wishlist_Items                 46000 non-null  float64
#  10  Total_Purchases                50000 non-null  float64
#  11  Average_Order_Value            50000 non-null  float64
#  12  Days_Since_Last_Purchase       47000 non-null  float64
#  13  Discount_Usage_Rate            46500 non-null  float64
#  14  Returns_Rate                   45509 non-null  float64
#  15  Email_Open_Rate                47472 non-null  float64
#  16  Customer_Service_Calls         49832 non-null  float64
#  17  Product_Reviews_Written        46500 non-null  float64
#  18  Social_Media_Engagement_Score  44000 non-null  float64
#  19  Mobile_App_Usage               45000 non-null  float64
#  20  Payment_Method_Diversity       47500 non-null  float64
#  21  Lifetime_Value                 50000 non-null  float64
#  22  Credit_Balance                 44500 non-null  float64
#  23  Churned                        50000 non-null  int64
#  24  Signup_Quarter                 50000 non-null  str
# dtypes: float64(20), int64(1), str(4)
# memory usage: 10.4 MB

# %% [markdown]
# #### Обработка пропусков

# %%
def show_nan_info(data):
  nan_data = data.isna().sum()
  nan_data = nan_data[nan_data > 0].to_frame(name="nan_count")

  nan_data['nan_%'] = (nan_data["nan_count"] / data.shape[0]) * 100
  return nan_data.sort_values(by='nan_%', ascending=False)

nan_data = show_nan_info(raw_data)
nan_data
# Out:
#                                nan_count   nan_%
# Social_Media_Engagement_Score       6000  12.000
# Credit_Balance                      5500  11.000
# Mobile_App_Usage                    5000  10.000
# Returns_Rate                        4491   8.982
# Wishlist_Items                      4000   8.000
# Discount_Usage_Rate                 3500   7.000
# Product_Reviews_Written             3500   7.000
# Session_Duration_Avg                3399   6.798
# Pages_Per_Session                   3000   6.000
# Days_Since_Last_Purchase            3000   6.000
# Email_Open_Rate                     2528   5.056
# Payment_Method_Diversity            2500   5.000
# Age                                 2495   4.990
# Customer_Service_Calls               168   0.336

# %% [markdown]
# Посмотрим на то каких типов эти признаки

# %%
nan_cols_list = list(nan_data.index)
raw_data[nan_cols_list].dtypes
# Out:
# Social_Media_Engagement_Score    float64
# Credit_Balance                   float64
# Mobile_App_Usage                 float64
# Returns_Rate                     float64
# Wishlist_Items                   float64
# Discount_Usage_Rate              float64
# Product_Reviews_Written          float64
# Session_Duration_Avg             float64
# Pages_Per_Session                float64
# Days_Since_Last_Purchase         float64
# Email_Open_Rate                  float64
# Payment_Method_Diversity         float64
# Age                              float64
# Customer_Service_Calls           float64
# dtype: object

# %%
data = raw_data

# %% [markdown]
# Проанализируем каждый из признаков с пропусками:
#  - Построим распределение числовых значений
#  - Проверим возможность заполнения нулем или медианой

# %% [markdown]
# ##### Social_Media_Engagement_Score

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x='Social_Media_Engagement_Score', data=raw_data)
plt.show()

# %% [markdown]
# Признак имеет большой бизнес смысл, пока подумай что с ним делать.

# %%
data['Social_Media_Engagement_Score'] = data.groupby('Gender')['Social_Media_Engagement_Score'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ##### Credit_Balance

# %%
sns.boxplot(x='Credit_Balance', data=raw_data)
plt.show()

# %% [markdown]
# Этот признак имеет большие значения, лучше заполнить пропуски медианой сгруппированной по полу

# %%
data['Credit_Balance'] = data.groupby('Gender')['Credit_Balance'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ##### Mobile_App_Usage

# %%
sns.boxplot(x='Mobile_App_Usage', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает использование мобильного приложения, логично заполнить пропуски нулем

# %%
data['Mobile_App_Usage'] = data['Mobile_App_Usage'].fillna(0)

# %% [markdown]
# ##### Returns_Rate

# %%
sns.boxplot(x='Returns_Rate', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество возвратов, логично заполнить пропуски нулем

# %%
data['Returns_Rate'] = data['Returns_Rate'].fillna(0)

# %% [markdown]
# ##### Wishlist_Items

# %%
sns.boxplot(x='Wishlist_Items', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество товаров в избранном, логично заполнить пропуски нулем, так как в избранном может не быть ни одного товара

# %%
data['Wishlist_Items'] = data['Wishlist_Items'].fillna(0)

# %% [markdown]
# ##### Discount_Usage_Rate

# %%
sns.boxplot(x='Discount_Usage_Rate', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество скидок, логично заполнить пропуски нулем, так как можно не пользоваться скидками, либо не иметь покупок

# %%
data['Discount_Usage_Rate'] = data['Discount_Usage_Rate'].fillna(0)

# %% [markdown]
# ##### Product_Reviews_Written

# %%
sns.boxplot(x='Product_Reviews_Written', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество написанных отзывов, логично заполнить пропуски нулем

# %%
data['Product_Reviews_Written'] = data['Product_Reviews_Written'].fillna(0)

# %% [markdown]
# ##### Session_Duration_Avg

# %%
sns.boxplot(x='Session_Duration_Avg', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает среднюю длительность на сайте, заполним пустые значения медианой по полу

# %%
data['Session_Duration_Avg'] = data.groupby('Gender')['Session_Duration_Avg'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ##### Pages_Per_Session

# %%
sns.boxplot(x='Pages_Per_Session', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество просмотренных страниц, заполним пропуски средним значением по полу

# %%
data['Pages_Per_Session'] = data.groupby('Gender')['Pages_Per_Session'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ##### Days_Since_Last_Purchase

# %%
sns.boxplot(x='Days_Since_Last_Purchase', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество дней с прошлого заказа, логично заполнить пропуски нулем, так как это может быть первый заказ

# %%
data['Days_Since_Last_Purchase'] = data['Days_Since_Last_Purchase'].fillna(0)

# %% [markdown]
# ##### Email_Open_Rate

# %%
sns.boxplot(x='Email_Open_Rate', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает долю открытия почты, логично заполнить пропуски нулем

# %%
data['Email_Open_Rate'] = data['Email_Open_Rate'].fillna(0)

# %% [markdown]
# ##### Payment_Method_Diversity

# %%
sns.histplot(x='Payment_Method_Diversity', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает способ оплаты, заполним его медианой

# %%
data['Payment_Method_Diversity'] = data['Payment_Method_Diversity'].fillna(data['Payment_Method_Diversity'].median())

# %% [markdown]
# ##### Age

# %%
sns.boxplot(x='Age', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает способ оплаты, заполним его медианой сгруппированной по полу

# %%
data['Age'] = data.groupby('Gender')['Age'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# ##### Customer_Service_Calls

# %%
sns.boxplot(x='Customer_Service_Calls', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество звонков в поддержку, заполним признак нулем

# %%
data['Customer_Service_Calls'] = data['Customer_Service_Calls'].fillna(0)

# %% [markdown]
# Все признаки float. Вероятно это связано, что к этому типу приводится при наличии Nan
# - Часть признаков описвает число определенных действий. Можно предположить что Nan находится там, где этих действий 0. (то есть ничего не происходило)
# - Проверим какие из этих признаков не содержат 0

# %%
nan_cols_without_zero = []

for feat in nan_cols_list:
  if 0 not in raw_data[feat].values:
    nan_cols_without_zero.append(feat)
nan_cols_without_zero
# Out:
# ['Discount_Usage_Rate',
#  'Session_Duration_Avg',
#  'Pages_Per_Session',
#  'Payment_Method_Diversity',
#  'Age']

# %% [markdown]
# Это кандидаты по заполнению Nan нулями
# - Однако то, что они не содержат 0 это логично. Они не относятся к категории, которуя описана выше.
# - Поэтому пока этот анализ результатов не дал, проверим другие стратегии по работе с пропусками в этих колонаках.

# %% [markdown]
# - Подумаем над тем, по каким признакам можно просто исключить строки (dropna). Логично будет это сделать посмотрев корреляцию признаков с целевой переменной, в нашем случае это Churn.

# %%
import seaborn as sns

for_corr = raw_data[nan_cols_list + ['Churned']].corr()['Churned'].sort_values(ascending=False)
sns.heatmap(for_corr.to_frame(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
# да, коореляция не всегда бывает прямая, но в контесте объема датасета в 50К, считаем,
# что можно удалить пропуски в наиболее "отдаленных" от целевой переменной признаков.

cols_to_drop = ['Payment_Method_Diversity', 'Returns_Rate', 'Discount_Usage_Rate']


print("До очистки", raw_data.shape)
raw_data = raw_data.dropna(subset=cols_to_drop)
print(raw_data.shape)
# Out:
# До очистки (50000, 25)
# (40177, 25)

# %%
show_nan_info(raw_data.dropna(subset=cols_to_drop))
# Out:
# Empty DataFrame
# Columns: [nan_count, nan_%]
# Index: []

# %% [markdown]
# Вернемся к количественным признакам, в которых Nan означают отсутсвие чего-либо, тоесть их можно грубо заменить на 0.

# %%
nan_to_zero_cols  = ['Social_Media_Engagement_Score',
                     'Mobile_App_Usage',
                     'Wishlist_Items',
                     'Product_Reviews_Written',
                     'Customer_Service_Calls',
                     ]
for col in nan_to_zero_cols:
  raw_data[col] = raw_data[col].fillna(0)

# смотрим текущую статистику по пропускам
show_nan_info(raw_data)
# Out:
#                           nan_count      nan_%
# Credit_Balance                 4447  11.068522
# Session_Duration_Avg           2754   6.854668
# Days_Since_Last_Purchase       2429   6.045748
# Pages_Per_Session              2337   5.816761
# Age                            2029   5.050153
# Email_Open_Rate                2006   4.992906

# %% [markdown]
# #### TODO
# но для следующих этапов уже можно использовать

# %% [markdown]
# #### Обработка выбросов

# %% [markdown]
# Для обработки выбросов проанализирую то, какие значения принимают признаки, построив диаграмму

# %%
import numpy as np
import matplotlib.pyplot as plt

# посмотрю на распределения всех числовых типов и опеределю, где необходимо удалять выбросы
# для наглядности распределения логарифмирую
def plot_log_boxplots(df):
    # num_df = df.select_dtypes(include=['number'])
    log_df = df.apply(lambda col: np.log(col + 1) if col.min() >= 0 else col)

    plt.figure(figsize=(15, 8))
    # log_df.boxplot()
    df.boxplot()
    plt.show()

plot_log_boxplots(raw_data[[
                     'Session_Duration_Avg',
                     'Pages_Per_Session',
                     'Age',
                     ]])

# %% [markdown]
# Видно "неадекватные" значения для age. Можно обрезать до стандартного (0,90)

# %%
raw_data['Age'] = raw_data['Age'].clip(0, 90)

# %%
# диапазон (0, 100) для признаков _Rate
plot_log_boxplots(raw_data[
    ['Email_Open_Rate']
])

# todo
raw_data['Email_Open_Rate'] = raw_data['Email_Open_Rate'].clip(0, 90)

# %% [markdown]
# #### Поиск дупликатов

# %%
print("Число дубликатов до:", raw_data.duplicated().sum())
data = raw_data.drop_duplicates()
print("Число дубликатов после:", raw_data.duplicated().sum())
# Out:
# Число дубликатов до: 0
# Число дубликатов после: 0

# %% [markdown]
# По данным видно что всё поведения пользователя сводится к следующим типам:
#
# - Просмотр товара на странице (view)
# - Добавление товара в корзину (addtocart)
# - Покупка товара (transaction)
#
# Тут можно наблюдать некую воронку: все кто дошел до transaction - купил товар на сайте, в дальнейшем сделаем из этого целевой признак.

# %% [markdown]
# На этом этапе логично предположить что пропуски в transactionid связаны с тем что покупка не была совершена.
# Поэтому создадим булевый признак has_transaction, отвечающий на вопрос "Была ли совершена покупка?"
# Пропуски же в признаке transaction_id убирать не стоить, т.к. это оставит выборку только покупок, и "закроет глаза" на случае когда пользователь покупку не совершил. Оставим эти пропуски как "осознанные" в контексте решаемой задачи.

# %%
raw_data.describe(percentiles=[0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
#                 Age  Membership_Years  Login_Frequency  Session_Duration_Avg  \
# count  50000.000000      50000.000000     50000.000000          50000.000000
# mean      37.751800          2.984009        11.624660             27.599070
# std       11.230378          2.059105         7.810657             10.497494
# min        5.000000          0.100000         0.000000              1.000000
# 50%       37.000000          2.500000        11.000000             26.800000
# 75%       45.000000          4.000000        17.000000             34.000000
# 90%       53.000000          5.800000        22.000000             41.900000
# 95%       57.000000          7.100000        26.000000             46.700000
# 99%       65.000000         10.000000        32.000000             55.000000
# max       90.000000         10.000000        46.000000             75.600000
#
#        Pages_Per_Session  Cart_Abandonment_Rate  Wishlist_Items  \
# count       50000.000000           50000.000000    50000.000000
# mean            8.717542              57.079973        3.954520
# std             3.663996              16.282723        3.274206
# min             1.000000               0.000000        0.000000
# 50%             8.400000              58.100000        3.000000
# 75%            11.000000              68.700000        6.000000
# 90%            13.700000              77.200000        8.000000
# 95%            15.300000              81.900000       10.000000
# 99%            18.200000              90.800000       14.000000
# max            24.100000             143.743350       28.000000
#
#        Total_Purchases  Average_Order_Value  Days_Since_Last_Purchase  ...  \
# count     50000.000000         50000.000000              50000.000000  ...
# mean         13.111576           123.117330                 28.005300  ...
# std           7.017312           175.569714                 29.647097  ...
# min         -13.000000            26.380000                  0.000000  ...
# 50%          12.000000           112.970000                 19.000000  ...
# 75%          17.000000           144.440000                 39.000000  ...
# 90%          22.000000           179.000000                 67.000000  ...
# 95%          24.700000           201.821000                 87.000000  ...
# 99%          31.200000           252.300100                136.000000  ...
# max         128.700000          9666.379178                287.000000  ...
#
#        Returns_Rate  Email_Open_Rate  Customer_Service_Calls  \
# count  50000.000000     50000.000000             50000.00000
# mean       6.080833        19.879322                 5.66274
# std        6.164110        14.625496                 2.69171
# min        0.000000         0.000000                 0.00000
# 50%        4.900000        18.800000                 5.00000
# 75%        8.600000        29.700000                 7.00000
# 90%       12.800000        39.900000                 9.00000
# 95%       15.700000        46.100000                10.00000
# 99%       21.600000        57.000000                13.00000
# max       99.615734        90.000000                21.00000
#
#        Product_Reviews_Written  Social_Media_Engagement_Score  \
# count             50000.000000                   50000.000000
# mean                  2.653580                      29.156242
# std                   2.361001                      19.308463
# min                   0.000000                       0.000000
# 50%                   2.000000                      27.700000
# 75%                   4.000000                      40.700000
# 90%                   6.000000                      55.800000
# 95%                   7.000000                      64.700000
# 99%                  10.000000                      81.700000
# max                  21.000000                     100.000000
#
#        Mobile_App_Usage  Payment_Method_Diversity  Lifetime_Value  \
# count      50000.000000               50000.00000    50000.000000
# mean          17.434446                   2.33618     1440.626292
# std           10.659451                   1.08465      907.249443
# min            0.000000                   1.00000        0.000000
# 50%           17.200000                   2.00000     1243.415000
# 75%           24.600000                   3.00000     1874.000000
# 90%           31.500000                   4.00000     2637.133000
# 95%           35.600000                   4.00000     3192.503500
# 99%           42.900000                   5.00000     4420.197400
# max           61.900000                   5.00000     8987.240000
#
#        Credit_Balance       Churned
# count    50000.000000  50000.000000
# mean      1958.434800      0.289000
# std       1155.952428      0.453302
# min          0.000000      0.000000
# 50%       1899.000000      0.000000
# 75%       2664.000000      1.000000
# 90%       3520.000000      1.000000
# 95%       4019.000000      1.000000
# 99%       5004.010000      1.000000
# max       7197.000000      1.000000
#
# [10 rows x 21 columns]

# %% [markdown]
# Просто угадать перцентиль нельзя, это может отрезать важную информацию в выборке, поэтому найдем оптимальный перцентиль при условии, что мы готовы "выбросить" не более 10% событий на сайте

# %%
# def compare_percentiles(data_by_visitors, range_percentiles, threshold_data_percent=1):
#   info = {}
#   for per in range_percentiles:
#     treshold = data_by_visitors.quantile(per)
#     removed_visitors = (data_by_visitors > treshold).sum()
#     removed_persent = (removed_visitors/ (data_by_visitors).count()) * 100
#     info.update([(round(per, 2), round(removed_persent, 2))])
#     print(f"Перцентиль:{round(per, 2)}, Процент удаленных пользователей: {round(removed_persent, 2)}")
#   return info

# %%
# _ = compare_percentiles(data_by_visitors=raw_data, range_percentiles=[0.5, 0.75, 0.9, 0.95, 0.99])

# %% [markdown]
# Общая картина понятна, сделаю прогон автомтически для подбора идеального перцентиля

# %%
# import numpy as np
# per_list = np.arange(0.5, 0.9, 0.01)
# res_dict = compare_percentiles(data_by_visitors=data_by_visitors, range_percentiles=per_list)

# %%
# threshold_data_percent = 10

# def get_best_percentile(dict_, treshold):
#   res = []
#   for k, v in dict_.items():
#     if v < threshold_data_percent:
#       res.append(k)
#   return res[0]

# best_perc = get_best_percentile(res_dict, threshold_data_percent)
# best_perc

# %% [markdown]
# Получили лучший перецентль для удаления выбросов

# %%
# data_by_visitors.describe(percentiles=[best_perc])

# %%
df = raw_data

# %% [markdown]
# ### Создание новых признаков

# %%
df.head(15)
# Out:
#      Age  Gender  Country        City  Membership_Years  Login_Frequency  \
# 0   43.0    Male   France   Marseille               2.9             14.0
# 1   36.0    Male       UK  Manchester               1.6             15.0
# 2   45.0  Female   Canada   Vancouver               2.9             10.0
# 3   56.0  Female      USA    New York               2.6             10.0
# 4   35.0    Male    India       Delhi               3.1             29.0
# 5   35.0    Male    Japan       Tokyo               3.5              6.0
# 6   56.0    Male  Germany      Berlin               1.9             24.0
# 7   47.0  Female      USA     Houston               1.6             14.0
# 8   32.0    Male   Canada     Calgary               1.3             14.0
# 9   44.0    Male      USA    New York               3.6             13.0
# 10  32.0    Male       UK     Glasgow               0.9              0.0
# 11  32.0  Female  Germany      Munich               0.6             11.0
# 12  40.0  Female      USA     Phoenix               7.1             10.0
# 13  18.0  Female      USA     Phoenix               3.1             13.0
# 14  18.0  Female   France       Paris               3.7             14.0
#
#     Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                   27.4                6.0                   50.6
# 1                   42.7               10.3                   37.7
# 2                   24.8                1.6                   70.9
# 3                   38.4               14.8                   41.7
# 4                   51.4                8.4                   19.1
# 5                   21.9                6.9                   74.4
# 6                   46.4               13.9                   36.2
# 7                   24.1                8.3                   59.9
# 8                   26.8                7.4                   66.5
# 9                   31.3                5.4                   62.6
# 10                  12.3                2.9                   73.5
# 11                  12.1                5.6                   77.2
# 12                  19.2                7.0                   69.1
# 13                  26.1                8.9                   47.7
# 14                  33.5               10.3                   48.4
#
#     Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0              3.0  ...             17.9                     9.0
# 1              1.0  ...             42.8                     7.0
# 2              1.0  ...              0.0                     4.0
# 3              9.0  ...             41.4                     2.0
# 4              9.0  ...             37.9                     1.0
# 5              0.0  ...             16.0                     8.0
# 6              5.0  ...             35.5                     4.0
# 7              2.0  ...              5.5                     5.0
# 8              4.0  ...             19.0                     2.0
# 9              3.0  ...             11.7                     2.0
# 10             0.0  ...              0.0                    11.0
# 11             0.0  ...              4.0                     7.0
# 12             6.0  ...              9.6                     4.0
# 13             2.0  ...             19.0                     8.0
# 14             2.0  ...             16.1                     6.0
#
#     Product_Reviews_Written  Social_Media_Engagement_Score  Mobile_App_Usage  \
# 0                       4.0                           16.3              20.8
# 1                       3.0                           27.5              23.3
# 2                       1.0                           27.7               8.8
# 3                       5.0                           85.9              31.0
# 4                      11.0                           83.0              50.4
# 5                       2.0                           14.3              11.2
# 6                       6.0                           68.8              42.9
# 7                       0.0                           30.1               7.6
# 8                       0.0                            0.0              18.7
# 9                       1.0                           13.5              21.5
# 10                      2.0                           17.0               8.0
# 11                      1.0                            0.0              17.7
# 12                      0.0                           17.7               0.0
# 13                      4.0                           27.7              21.5
# 14                      4.0                           28.3              23.3
#
#     Payment_Method_Diversity  Lifetime_Value  Credit_Balance  Churned  \
# 0                        1.0          953.33          2278.0        0
# 1                        3.0         1067.47          3028.0        0
# 2                        2.0         1289.75          2317.0        0
# 3                        3.0         2340.92          2674.0        0
# 4                        4.0         3041.29          5354.0        0
# 5                        2.0         1995.43          2418.0        1
# 6                        5.0         3003.57          2657.0        0
# 7                        2.0         1394.04          2274.0        0
# 8                        2.0          537.21           534.0        0
# 9                        2.0          807.84           977.0        0
# 10                       1.0          599.41           498.0        1
# 11                       2.0          335.92          1369.0        1
# 12                       4.0         1229.94          2446.0        0
# 13                       3.0         1083.91          2772.0        1
# 14                       3.0         1618.51          3624.0        0
#
#     Signup_Quarter
# 0               Q1
# 1               Q4
# 2               Q4
# 3               Q1
# 4               Q4
# 5               Q1
# 6               Q1
# 7               Q4
# 8               Q1
# 9               Q2
# 10              Q2
# 11              Q3
# 12              Q1
# 13              Q3
# 14              Q1
#
# [15 rows x 25 columns]

# %% [markdown]
# One Hot признаки

# %%
df['Signup_Quarter'].value_counts()
# Out:
# Signup_Quarter
# Q3    12558
# Q2    12521
# Q4    12468
# Q1    12453
# Name: count, dtype: int64

# %%
df['Payment_Method_Diversity'].value_counts()
# Out:
# Payment_Method_Diversity
# 2.0    19199
# 3.0    11847
# 1.0    11795
# 4.0     4720
# 5.0     2439
# Name: count, dtype: int64

# %%
df = pd.get_dummies(data=df, columns=['Signup_Quarter', 'Payment_Method_Diversity'])

# %%
df['Make_Wishlists'] = df['Wishlist_Items'] > 0

# %% [markdown]
# Покупательная способность на один год

# %%
df['User_Revenue'] = df['Total_Purchases'] * df['Average_Order_Value'] / df['Membership_Years']

# %% [markdown]
# Ценность клиента в год

# %%
df['Lifetime_Per_Year'] = df['Lifetime_Value'] / df['Membership_Years']

# %% [markdown]
# Число покупок в год

# %%
# / df['Membership_Years']

# %% [markdown]
# Звонков в поддержку в год

# %%
# / df['Membership_Years']

# %% [markdown]
# Численное значение пола

# %%
df['Gender'].unique()
# Out:
# <ArrowStringArray>
# ['Male', 'Female', 'Other']
# Length: 3, dtype: str

# %%
df['Gender_code'] = df['Gender'].map({
    'Male': 0,
    'Female': 1,
    'Other': 2
})

# %% [markdown]
# Аналогично чего-то "в год" можно пересобрать в признаки: "на одну покупку" т.е. / df['Total_Purchases']

# %% [markdown]
# Можно придумать фичу про реакцию на Discount_Rate

# %% [markdown]
# Еще можно собрать "плохие признаки воедино" Cart_Abandonment_Rate, Returns_Rate ...

# %% [markdown]
# Еще идея если сложно можно не юзать: В зависимости от средней зп в стране/городе больше или меньше рейтить покупателя (какой то словарик с ЗП подтянуть из интернета)

# %%
df['Country'].unique()
# Out:
# <ArrowStringArray>
# ['France', 'UK', 'Canada', 'USA', 'India', 'Japan', 'Germany', 'Australia']
# Length: 8, dtype: str

# %% [markdown]
# Примерные актуальные значения средней месячной зарплаты после выплаты налогов в долларах

# %%
country_income = {
    'France': 2800,
    'UK': 3200,
    'USA': 5200,
    'India': 450,
    'Japan': 2600,
    'Germany': 3300,
    'Canada': 3900,
    'Australia': 4500
}

# %%
df['monthly_income'] = df['Country'].map(country_income)

# %%
df
# Out:
#         Age  Gender Country         City  Membership_Years  Login_Frequency  \
# 0      43.0    Male  France    Marseille               2.9             14.0
# 1      36.0    Male      UK   Manchester               1.6             15.0
# 2      45.0  Female  Canada    Vancouver               2.9             10.0
# 3      56.0  Female     USA     New York               2.6             10.0
# 4      35.0    Male   India        Delhi               3.1             29.0
# ...     ...     ...     ...          ...               ...              ...
# 49995  38.0  Female     USA  Los Angeles              10.0             10.0
# 49996  37.0    Male     USA      Chicago               1.4             21.0
# 49997  44.0  Female     USA      Phoenix               2.8             19.0
# 49998  41.0  Female     USA      Chicago               2.9             17.0
# 49999  56.0    Male      UK        Leeds               2.2              2.0
#
#        Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                      27.4                6.0                   50.6
# 1                      42.7               10.3                   37.7
# 2                      24.8                1.6                   70.9
# 3                      38.4               14.8                   41.7
# 4                      51.4                8.4                   19.1
# ...                     ...                ...                    ...
# 49995                  35.8                8.8                   51.2
# 49996                  32.4                9.6                   32.5
# 49997                  40.3               10.4                   50.6
# 49998                  29.9               10.1                   60.8
# 49999                  18.2                8.4                   46.0
#
#        Wishlist_Items  ...  Payment_Method_Diversity_1.0  \
# 0                 3.0  ...                          True
# 1                 1.0  ...                         False
# 2                 1.0  ...                         False
# 3                 9.0  ...                         False
# 4                 9.0  ...                         False
# ...               ...  ...                           ...
# 49995             3.0  ...                          True
# 49996             2.0  ...                         False
# 49997             1.0  ...                          True
# 49998             1.0  ...                         False
# 49999             0.0  ...                          True
#
#        Payment_Method_Diversity_2.0  Payment_Method_Diversity_3.0  \
# 0                             False                         False
# 1                             False                          True
# 2                              True                         False
# 3                             False                          True
# 4                             False                         False
# ...                             ...                           ...
# 49995                         False                         False
# 49996                         False                         False
# 49997                         False                         False
# 49998                         False                          True
# 49999                         False                         False
#
#        Payment_Method_Diversity_4.0  Payment_Method_Diversity_5.0  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                              True                         False
# ...                             ...                           ...
# 49995                         False                         False
# 49996                          True                         False
# 49997                         False                         False
# 49998                         False                         False
# 49999                         False                         False
#
#        Make_Wishlists  User_Revenue  Lifetime_Per_Year  Gender_code  \
# 0                True    293.958621         328.734483            0
# 1                True   1004.859375         667.168750            0
# 2                True    519.390345         444.741379            1
# 3                True    849.980769         900.353846            1
# 4                True   1481.370968         981.061290            0
# ...               ...           ...                ...          ...
# 49995            True    203.788000         236.598000            1
# 49996            True   1106.892857         924.000000            0
# 49997            True    597.600000         591.171429            1
# 49998            True    461.710345         443.486207            1
# 49999           False    542.740909         487.550000            0
#
#        monthly_income
# 0                2800
# 1                3200
# 2                3900
# 3                5200
# 4                 450
# ...               ...
# 49995            5200
# 49996            5200
# 49997            5200
# 49998            5200
# 49999            3200
#
# [50000 rows x 37 columns]

# %%
df.to_csv("data_iter1.csv", index=False)
