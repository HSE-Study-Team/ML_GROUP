# %% [markdown]
# # Машинное обучение, MDS
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Групповой проект. Machine Learning

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 30.05.2026
#
# __Дедлайн по записи в таблицу:__ 4:00 05.06.2026
#
# __Дедлайн по загрузке работ:__ 4:00 17.06.2026
#
# __Защита проекта:__ ~ 18.06.2026 — 19.06.2026

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняемому ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой в обязательном порядке проверяется и учитывается в оценке вклад **каждого участника** в общую работу команды. Вследствие этого крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости команда большинством голосов имеет право исключить человека из команды **до загрузки работ** в Google форму (будет опубликована в чате позднее), сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1M2OpQfRmX8nVQPZcxBFpf_fVxIFl31RXx22BFXMj054/edit?usp=sharing

# %% [markdown]
# ## Отправка материалов группового проекта

# %% [markdown]
# Во избежание использования при выполнении группового проекта генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации (например, для автоматической генерации кода), **одному из участников команды** необходимо предварительно загрузить работу в форму. Наличие сгенерированного кода или любого другого случая "несанкционированного" использования нейросетей будет считаться плагиатом, и такой проект будет оценен в 0 баллов для всех участников. При отсутствии своевременно загруженных файлов с проектом команде также выставляется 0 за проект.
#
# *Примечание: презентацию проекта загружать необязательно, важно отправить содержательные файлы с кодом и ссылку на репозиторий GitHub (при наличии).*

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(29052026)`.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции.

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современной бизнес-индустрии использование машинного обучения и искусственного интеллекта приобретает критическое значение. Компании, стремящиеся оставаться конкурентоспособными, активно внедряют данные технологии для анализа данных, автоматизации процессов и прогнозирования тенденций. Это позволяет бизнесу в целом принимать более обоснованные решения, а также стараться оперативно реагировать на изменения рынка.
#
# В данном проекте вы на реальных данных попрактикуетесь в том, как осуществляется построение предсказательных моделей машинного обучения, как впоследствии эти модели применяются, а также в том, как происходит поиск скрытых закономерностей и полезных инсайтов, которые в дальнейшем помогают компаниям оптимизировать свои бизнес-процессы.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже вашему вниманию предлагаются примерные этапы реализации проекта:
#
# - Выбор компании и/или платформы;
# - Формулировка двух связанных бизнес-задач, которые могла бы хотеть решить компания/платформа на основе данных, используя современные методы классического машинного обучения;
# - Обоснование сформулированных бизнес-задач и описание того, как предлагаемое решение вписывается в бизнес-процессы компании;
# - Получение необходимых данных путём поиска открытых источников/датасетов, парсинга/работы с API;
# - Формулировка задач в терминах машинного обучения, для решения поставленных бизнес-задач;
# - Выбор и обоснование возможного пула методов и алгоритмов для решения сформулированных задач машинного обучения;
# - Первичная обработка данных;
# - Применение методов машинного обучения для решения поставленных задач;
# - Получение и агрегация результатов, финальные выводы.

# %% [markdown]
# ### Требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию и защитить ее перед комиссией.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных с платформы; дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных; и главное, безусловно, — дата-саентистов: реализовать поставленные задачи с помощью методов машинного обучения и извлечь полезные инсайты из проделанной работы. А в конце, конечно, — презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект исходя из того, что ваша цель — представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10-балльной шкале, исходя из 5 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задач и бизнес-обоснование (до 3 баллов)
#
# Данный критерий оценивает, насколько обоснованными, осмысленными и **содержательно связанными** получились две решаемые в проекте бизнес-задачи; насколько полно был осуществлён переход от бизнес-задач к задачам машинного обучения (насколько в реальности постановка задач соответствует исходной постановке задачи с точки зрения интересов компании); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.
#
# *По данному критерию можно получить **3 балла** только при условии, что в презентации представлена схема, иллюстрирующая, как предлагаемое решение вписывается в бизнес-процессы компании: откуда поступают данные, каким образом они обрабатываются, как модель генерирует предсказания и в каком формате эти предсказания используются для принятия бизнес-решений. Строгая нотация не обязательна — важна логика и понятность схемы для стороннего наблюдателя.*

# %% [markdown]
# ### Критерий 2. Инструменты извлечения и обработки данных (до 2 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных ручным и автоматизированным образом, использованные средства предобработки, подготовки данных и EDA. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.

# %% [markdown]
# ### Критерий 3. Инструменты машинного обучения (до 5 баллов)
#
# Данный критерий оценивает применение методов машинного обучения в проекте. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным. Кроме того, будет оценен сравнительный анализ моделей, использованных в решении.
#
# *__Важно:__ в случае **оценки меньше 1 балла** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **2 балла** только при условии осмысленного использования в проекте, помимо моделей машинного обучения, минимум трех объектов Transformer различной природы (Scaler'ы, алгоритмы снижения размерностей и прочее).*
#
# *По данному критерию можно получить **3 балла** только при условии осуществления сравнительного анализа эффективности различных моделей машинного обучения внутри вашего проекта на одних и тех же данных. Самих моделей машинного обучения должно быть не менее 5; их природа должна отличаться (например, деревья и случайный лес — это алгоритмы разной природы, а вот модели CatBoost и LightGBM — нет); их использование, как и настройка гиперпараметров, должны быть подробно описаны и обоснованы. Кроме того, в рамках сравнительного анализа должны быть получены и сформулированы явные, значимые выводы о сравнительной эффективности того или иного алгоритма.*
#
# *По данному критерию можно получить **4 балла** только при условии корректного и обоснованного применения в проекте двух инструментов/подходов/библиотек, не рассматривавшихся на соответствующих семинарах и лекциях.*
#
# *По данному критерию можно получить **5 баллов** только при условии, что как минимум одна модель внутри сравнительного анализа представляет собой нейронную сеть (для решения задачи классического машинного обучения).*

# %% [markdown]
# ## Этап 0. Авторы проекта
#
# https://github.com/HSE-Study-Team/ML_GROUP
#
# ```
# Примак Андрей Сергеевич
# Шумай Артём
# Карташов Роман Олегович
# Репинская Вероника Вадимовна
# Красноперов Максим Алексеевич
# ```

# %% [markdown]
# ## Этап 1. Предварительная обработка данных

# %% [markdown]
# ### Загрузка исходного файла

# %%
# from google.colab import files
# uploaded = files.upload()

# https://www.kaggle.com/datasets/dhairyajeetsingh/ecommerce-customer-behavior-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

raw_data = pd.read_csv("ecommerce_customer_churn_dataset.csv", encoding='UTF-8', sep=',')

# %%
raw_data.head()
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
# 3  56.0  Female     USA    New York               2.6             10.0
# 4  35.0    Male   India       Delhi               3.1             29.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
# 4                  51.4                NaN                   19.1
#
#    Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0             3.0  ...             17.9                     9.0
# ...

# %% [markdown]
# ### Описание признаков датасета

# %% [markdown]
# | Признак | Описание |
# |--------|----------|
# | **Age** | Возраст клиента |
# | **Gender** | Пол клиента  |
# | **Country** | Страна проживания клиента |
# | **City** | Город проживания клиента|
# | **Membership_Years** | Длительность клиентского стажа |
# | **Login_Frequency** | Частота входов на сайт |
# | **Session_Duration_Avg** | Средняя длительность сессии на сайте |
# | **Pages_Per_Session** | Среднее число страниц, просмотренных за сессию |
# | **Cart_Abandonment_Rate** | Доля брошенных корзин |
# | **Wishlist_Items** | Число товаров в избранном |
# | **Email_Open_Rate** | Доля открытия рассылок на почте |
# | **Mobile_App_Usage** | Использование мобильного приложения |
# | **Social_Media_Engagement_Score** | Уровень вовлеченности клиента через соцсети |
# | **Total_Purchases** | Общее число покупок |
# | **Average_Order_Value** | Средний чек при покупке |
# | **Days_Since_Last_Purchase** | Число дней с момента последней покупки |
# | **Discount_Usage_Rate** | Доля заказов со скидкой |
# | **Return_Rate** | Доля возвратов |
# | **Payment_Method_Diversity** | Число способов оплаты |
# | **Customer_Service_Calls** | Число звонков в поддержку |
# | **Product_Reviews_Written** | Число написанных отзывов |
# | **Lifetime_Value** | Суммарная выручка от клиента |
# | **Credit_Balance** | Баланс клиента |
# | **Signup_Quarter** | Квартал регистрации клиента|
# | **Churned** | Факт оттока клиента |

# %% [markdown]
# ### Поиск дубликатов

# %%
raw_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            47505 non-null  float64
#  1   Gender                         50000 non-null  object
#  2   Country                        50000 non-null  object
#  3   City                           50000 non-null  object
#  4   Membership_Years               50000 non-null  float64
#  5   Login_Frequency                50000 non-null  float64
#  6   Session_Duration_Avg           46601 non-null  float64
#  7   Pages_Per_Session              47000 non-null  float64
#  8   Cart_Abandonment_Rate          50000 non-null  float64
#  9   Wishlist_Items                 46000 non-null  float64
#  10  Total_Purchases                50000 non-null  float64
#  11  Average_Order_Value            50000 non-null  float64
# ...

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# #### Анализ числа пропусков

# %%
raw_data.isna().sum()
# Out:
# Age                              2495
# Gender                              0
# Country                             0
# City                                0
# Membership_Years                    0
# Login_Frequency                     0
# Session_Duration_Avg             3399
# Pages_Per_Session                3000
# Cart_Abandonment_Rate               0
# Wishlist_Items                   4000
# Total_Purchases                     0
# Average_Order_Value                 0
# Days_Since_Last_Purchase         3000
# Discount_Usage_Rate              3500
# Returns_Rate                     4491
# Email_Open_Rate                  2528
# Customer_Service_Calls            168
# Product_Reviews_Written          3500
# Social_Media_Engagement_Score    6000
# Mobile_App_Usage                 5000
# Payment_Method_Diversity         2500
# Lifetime_Value                      0
# Credit_Balance                   5500
# Churned                             0
# Signup_Quarter                      0
# ...

# %%
def show_nan_info(data):
  "Находит пропуски в датасете, вычисляет процент nan от числа строк датасета, сортирует в порядке убывания"
  nan_data = data.isna().sum()
  nan_data = nan_data[nan_data > 0].to_frame(name="nan_count")

  nan_data['nan_%'] = (nan_data["nan_count"] / data.shape[0]) * 100
  return nan_data.sort_values(by='nan_%', ascending=False)

nan_data = show_nan_info(raw_data)
nan_data
# Out:
#                                nan_count   nan_%
# Social_Media_Engagement_Score       6000  12.000
# Credit_Balance                      5500  11.000
# Mobile_App_Usage                    5000  10.000
# Returns_Rate                        4491   8.982
# Wishlist_Items                      4000   8.000
# Discount_Usage_Rate                 3500   7.000
# Product_Reviews_Written             3500   7.000
# Session_Duration_Avg                3399   6.798
# Pages_Per_Session                   3000   6.000
# Days_Since_Last_Purchase            3000   6.000
# Email_Open_Rate                     2528   5.056
# Payment_Method_Diversity            2500   5.000
# Age                                 2495   4.990
# Customer_Service_Calls               168   0.336

# %% [markdown]
# Посмотрим на то каких типов эти признаки.

# %%
nan_cols_list = list(nan_data.index)
raw_data[nan_cols_list].dtypes
# Out:
# Social_Media_Engagement_Score    float64
# Credit_Balance                   float64
# Mobile_App_Usage                 float64
# Returns_Rate                     float64
# Wishlist_Items                   float64
# Discount_Usage_Rate              float64
# Product_Reviews_Written          float64
# Session_Duration_Avg             float64
# Pages_Per_Session                float64
# Days_Since_Last_Purchase         float64
# Email_Open_Rate                  float64
# Payment_Method_Diversity         float64
# Age                              float64
# Customer_Service_Calls           float64
# dtype: object

# %%
def show_top_nan():
  nan_data_show = raw_data[nan_cols_list].isna().mean()

  plt.figure(figsize=(10, 6))
  sns.barplot(x=nan_data_show.values, y=nan_data_show.index)
  plt.show()

# %% [markdown]
# Проанализируем каждый из признаков с пропусками:
#  - Построим распределение числовых значений
#  - Проверим возможность заполнения нулем или медианой

# %% [markdown]
# #### Процент вовлеченности клиента в социальных сетях: **Social_Media_Engagement_Score**

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Social_Media_Engagement_Score', data=raw_data)
plt.xlabel("Social_Media_Engagement_Score")
plt.show()

# %% [markdown]
# Признак имеет большой бизнес смысл.
# - Преобразуем в долю.
# - Предположим, что nan - означает, что пользователь был привлечен источниками, отличными от социальных сетей
# - Для отсутвующих значений создадим флаг Social_Media_Engagement_Missing = True.
# - Остальные nan заполним медианным значением.

# %%
raw_data['Social_Media_Engagement_Score'] = raw_data['Social_Media_Engagement_Score'] / 100.0
raw_data['Social_Media_Engagement_Missing'] = raw_data['Social_Media_Engagement_Score'].isna().astype(int)
raw_data['Social_Media_Engagement_Score'] = raw_data['Social_Media_Engagement_Score'].fillna(raw_data['Social_Media_Engagement_Score'].median())

# %% [markdown]
# #### Баланс клиента: **Credit_Balance**

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Credit_Balance', data=raw_data)
plt.xlabel("Credit_Balance")
plt.show()

# %% [markdown]
# Признак показывает баланс клиента.
# - Для отсутвующих значений создадим флаг Credit_Balance_Missing = True.
# - Остальные nan заполним медианным значением.

# %%
raw_data['Credit_Balance_Missing'] = raw_data['Credit_Balance'].isna().astype(int)
raw_data['Credit_Balance'] = raw_data['Credit_Balance'].fillna(raw_data['Credit_Balance'].median())

# %% [markdown]
# #### Число использований мобильного приложения: **Mobile_App_Usage**

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Mobile_App_Usage', data=raw_data)
plt.xlabel("Mobile_App_Usage")
plt.show()

# %% [markdown]
# Признак показывает число использований мобильного приложения.
# - Логично допустить, что есть информация nan, значит пользователь приложение не использовал. Заполним нулями.

# %%
raw_data['Mobile_App_Usage'] = raw_data['Mobile_App_Usage'].fillna(0)

# %% [markdown]
# #### Процент возвратов: **Returns_Rate**

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Returns_Rate', data=raw_data)
plt.xlabel("Returns_Rate")
plt.show()

# %% [markdown]
# Признак показывает процент возвратов (0-100).
# - Преобразуем в долю.
# - Для отсутвующих значений создадим флаг Return_Rate_Missing = True.
# - Остальные nan заполним медианным значением.

# %%
raw_data['Returns_Rate'] = raw_data['Returns_Rate'] / 100.0
raw_data['Returns_Rate_Missing'] = raw_data['Returns_Rate'].isna().astype(int)
raw_data['Returns_Rate'] = raw_data['Returns_Rate'].fillna(raw_data['Returns_Rate'].median())

# %% [markdown]
# #### Число товаров в избранном: **Wishlist_Items**

# %%
sns.boxplot(x='Wishlist_Items', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество товаров в избранном, логично заполнить пропуски нулем, так как в избранном может не быть ни одного товара.

# %%
raw_data['Mobile_App_Usage'] = raw_data['Wishlist_Items'].fillna(0)

# %% [markdown]
# #### Доля использования скидок: **Discount_Usage_Rate**

# %%
plt.figure(figsize=(8,5))
raw_data['Discount_Usage_Rate'].hist(bins=100)

plt.xlabel("Discount_Usage_Rate")
plt.show()

# %% [markdown]
# По аналогии других признаков датасеты с припиской _Rate - это должна быть доля использования скидок клиентами. Однако значения находятся в диапазоне (0-120), что странно.
# - Сделаем допущение: удалим Discount_Usage_Rate > 100 как "странные"
# - Преобразуем в долю.
# - Для отсутвующих значений создадим флаг Discount_Usage_Rate = True.
# - Остальные nan заполним медианным значением.

# %%
raw_data = raw_data[raw_data['Discount_Usage_Rate'] <= 100]
raw_data['Discount_Usage_Rate'] = raw_data['Discount_Usage_Rate'] / 100.0
raw_data['Discount_Usage_Rate_Missing'] = raw_data['Discount_Usage_Rate'].isna().astype(int)
raw_data['Discount_Usage_Rate'] = raw_data['Discount_Usage_Rate'].fillna(raw_data['Discount_Usage_Rate'].median())

# %% [markdown]
# #### Число написанных обзоров на товары: **Product_Reviews_Written**

# %%
raw_data['Product_Reviews_Written'].value_counts()
# Out:
# Product_Reviews_Written
# 1.0     8176
# 2.0     7855
# 3.0     6600
# 0.0     6166
# 4.0     4982
# 5.0     3593
# 6.0     2318
# 7.0     1431
# 8.0      926
# 9.0      481
# 10.0     258
# 11.0     129
# 12.0      68
# 13.0      42
# 14.0      19
# 15.0      12
# 16.0       2
# 21.0       1
# Name: count, dtype: int64

# %% [markdown]
# Нулей в уникальных значениях нет.
# - Значит nan == 0 отзывов, спокойно заменяем нулями.

# %%
raw_data['Product_Reviews_Written'] = raw_data['Product_Reviews_Written'].fillna(0)

# %% [markdown]
# #### Средняя длительность сессии: **Session_Duration_Avg**

# %%
sns.boxplot(x='Session_Duration_Avg', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает среднюю длительность сесии на сайте, заполним пустые значения медианой

# %%
raw_data['Session_Duration_Avg'] = raw_data['Session_Duration_Avg'].fillna(raw_data['Session_Duration_Avg'].median())

# %% [markdown]
# #### Число страниц за сессию: **Pages_Per_Session**

# %%
sns.boxplot(x='Pages_Per_Session', data=raw_data)
plt.show()

# %% [markdown]
# Признак число страниц за сессю на сайте, заполним пустые значения медианой

# %%
raw_data['Pages_Per_Session'] = raw_data['Pages_Per_Session'].fillna(raw_data['Pages_Per_Session'].median())

# %% [markdown]
# #### Число дней с момента последней покупки: **Days_Since_Last_Purchase**

# %%
sns.boxplot(x='Days_Since_Last_Purchase', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество дней с прошлого заказа
# - Здесь 0 означает, что покупка была сегодня, это значение имеет особый смысл.
# - Поэтому заполняем только медианой, без нулей.

# %%
raw_data['Days_Since_Last_Purchase'] = raw_data['Days_Since_Last_Purchase'].fillna(raw_data['Days_Since_Last_Purchase'].median())

# %% [markdown]
# #### Доля открытых писем: **Email_Open_Rate**

# %%
sns.boxplot(x='Email_Open_Rate', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает долю открытия почты
# - заменяет процент на долю /100
# - 0 может значить, что письма пришли, а клиент их не открыл
# - добавим признак Email_Open_Rate_Missig == True, где нет информации об открытии писем
# - остальное заполянем медианой

# %%
raw_data['Email_Open_Rate'] = raw_data['Email_Open_Rate'] / 100.0
raw_data['Email_Open_Rate_Missing'] = raw_data['Email_Open_Rate'].isna().astype(int)
raw_data['Email_Open_Rate'] = raw_data['Email_Open_Rate'].fillna(raw_data['Email_Open_Rate'].median())

# %% [markdown]
# #### Число используемых методов оплаты: **Payment_Method_Diversity**

# %%
sns.histplot(x='Payment_Method_Diversity', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает способ оплаты, заполним его медианой.
# - Добавим флаг об остутствии методов оплаты Payment_Method_Diversity_Missing
# - Заполним пропуски медианой

# %%
raw_data['Payment_Method_Diversity_Missing'] = raw_data['Payment_Method_Diversity'].isna().astype(int)
raw_data['Payment_Method_Diversity'] = raw_data['Payment_Method_Diversity'].fillna(raw_data['Payment_Method_Diversity'].median())

# %% [markdown]
# #### Возраст клиента: **Age**

# %%
plt.figure(figsize=(8,5))
raw_data['Age'].hist(bins=100)

plt.xlabel("Age")
plt.show()

# %% [markdown]
# Возраст клиента уместно заполнить медианой

# %%
raw_data['Age'] = raw_data.groupby('Gender')['Age'].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# #### Количество звонков в поддержку: **Customer_Service_Calls**

# %%
sns.boxplot(x='Customer_Service_Calls', data=raw_data)
plt.show()

# %% [markdown]
# Признак показывает количество звонков в поддержку, заполним признак нулем. То есть клиент не звонил в поддержку.

# %%
raw_data['Customer_Service_Calls'] = raw_data['Customer_Service_Calls'].fillna(0)

# %% [markdown]
# ### Обработка выбросов

# %% [markdown]
# Для обработки выбросов проанализирую то, какие значения принимают признаки, построив диаграмму

# %%
import numpy as np
import matplotlib.pyplot as plt

# посмотрю на распределения всех числовых типов и опеределю, где необходимо удалять выбросы
# для наглядности распределения логарифмирую
def plot_log_boxplots(df):
    # num_df = df.select_dtypes(include=['number'])
    log_df = df.apply(lambda col: np.log(col + 1) if col.min() >= 0 else col)

    plt.figure(figsize=(15, 8))
    # log_df.boxplot()
    df.boxplot()
    plt.show()

plot_log_boxplots(raw_data[[
                     'Session_Duration_Avg',
                     'Pages_Per_Session',
                     'Age',
                     ]])

# %% [markdown]
# Видно "неадекватные" значения для age. Можно обрезать до стандартного (0,90)

# %%
raw_data['Age'] = raw_data['Age'].clip(0, 90)

# %%
# диапазон (0, 100) для признаков _Rate
plot_log_boxplots(raw_data[
    ['Email_Open_Rate']
])

raw_data['Email_Open_Rate'] = raw_data['Email_Open_Rate'].clip(0, 90)

# %%
print("Число дубликатов до:", raw_data.duplicated().sum())
data = raw_data.drop_duplicates()
print("Число дубликатов после:", raw_data.duplicated().sum())
# Out:
# Число дубликатов до: 0
# Число дубликатов после: 0

# %% [markdown]
# ### Создание новых признаков

# %% [markdown]
# #### Новые признаки OHE: Signup_Quarter, Payment_Method_Diversity

# %%
raw_data.head(5)
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
# 3  56.0  Female     USA    New York               2.6             10.0
# 4  35.0    Male   India       Delhi               3.1             29.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
# 4                  51.4                8.4                   19.1
#
#    Wishlist_Items  ...  Lifetime_Value  Credit_Balance  Churned  \
# 0             3.0  ...          953.33          2278.0        0
# ...

# %%
raw_data['Signup_Quarter'].value_counts()
# Out:
# Signup_Quarter
# Q3    11682
# Q2    11631
# Q1    11598
# Q4    11382
# Name: count, dtype: int64

# %%
raw_data['Payment_Method_Diversity'].value_counts()
# Out:
# Payment_Method_Diversity
# 2.0    17798
# 1.0    10959
# 3.0    10955
# 4.0     4340
# 5.0     2241
# Name: count, dtype: int64

# %% [markdown]
# Используем OHE для категориального признака

# %%
raw_data = pd.get_dummies(data=raw_data, columns=['Signup_Quarter', 'Payment_Method_Diversity'])

# %% [markdown]
# #### Новый признак: **Make_Wishlists**

# %%
raw_data['Make_Wishlists'] = raw_data['Wishlist_Items'] > 0

# %% [markdown]
# #### Новый признак: **User_Revenue**

# %% [markdown]
# Покупательная способность на один год

# %%
raw_data['User_Revenue'] = raw_data['Total_Purchases'] * raw_data['Average_Order_Value'] / raw_data['Membership_Years']

# %% [markdown]
# #### Новый признак: Lifetime_Per_Year

# %% [markdown]
# Ценность клиента в год

# %%
raw_data['Lifetime_Per_Year'] = raw_data['Lifetime_Value'] / raw_data['Membership_Years']

# %% [markdown]
# #### Новый признак: **Gender_Code**

# %%
raw_data['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
raw_data['Gender_code'] = raw_data['Gender'].map({
    'Male': 0,
    'Female': 1,
    'Other': 2
})

# %% [markdown]
# #### Новый признак: **Monthly_Income**

# %% [markdown]
# Добавим новый признак среднего ежемесячного дохода по стране

# %%
raw_data['Country'].unique()
# Out:
# array(['France', 'UK', 'Canada', 'USA', 'India', 'Japan', 'Germany',
#        'Australia'], dtype=object)

# %% [markdown]
# Примерные актуальные значения средней месячной зарплаты после выплаты налогов в долларах

# %%
country_income = {
    'France': 2800,
    'UK': 3200,
    'USA': 5200,
    'India': 450,
    'Japan': 2600,
    'Germany': 3300,
    'Canada': 3900,
    'Australia': 4500
}

# %%
raw_data['monthly_income'] = raw_data['Country'].map(country_income)

# %% [markdown]
# ## Этап 2. Решение бизнес-задачи 1

# %% [markdown]
# На основе поведения и характеристик пользователя на сайте определить, с какой верятностью пользователь перестанет быть активным пользователем/покинет платформу.
# - Какие клиенты с наибольшей вероятностью могут уйти?
# - Кого из клиентов нужно удержать?

# %%
df = raw_data

# %%
df.head()
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
# 3  56.0  Female     USA    New York               2.6             10.0
# 4  35.0    Male   India       Delhi               3.1             29.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
# 4                  51.4                8.4                   19.1
#
#    Wishlist_Items  ...  Payment_Method_Diversity_1.0  \
# 0             3.0  ...                          True
# ...

# %% [markdown]
# ### Подготовка данных
# Убираем данные которые не влияют на отток.
# Закодировали страну как исторический отток из этой страны, но это лишь добавило шум в датасет. Поэтому убираем страну, решаем что для компании страна не сильно влияет на отток пользователей.
# Так же убрали:
# - среднюю длительность сессии, т.к она может быть выраженна через частоту логинов и количество страниц за сессию
# - количество покупок и среднюю цену заказа, т.к они и пожизненная ценность показывают схожие данные.

# %%
# Отбрасываем ненужные признаки
df_churn = df.drop(columns=['Signup_Quarter_Q1', 'Signup_Quarter_Q2',
                            'Signup_Quarter_Q3', 'Signup_Quarter_Q4',
                            'Payment_Method_Diversity_1.0', 'Payment_Method_Diversity_2.0',
                            'Payment_Method_Diversity_3.0', 'Payment_Method_Diversity_4.0', 'Payment_Method_Diversity_5.0',
                            'City',
                            'Session_Duration_Avg', # login_frequency + pages_per_session
                            'Total_Purchases', # lifetime value
                            'Average_Order_Value' # lifetime value
                            #'Make_Wishlists', 'User_Revenue'
                           ])

# %%
df_churn = pd.get_dummies(df_churn, columns=['Gender'], drop_first=True)
df_churn = df_churn.dropna()

# %%
print(f"Кол-во ушедших клиентов в датасете: {(df_churn['Churned'] == 1).sum()}, а оставшихся: {(df_churn['Churned'] == 0).sum()}")
# Out:
# Кол-во ушедших клиентов в датасете: 12391, а оставшихся: 30200

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import TargetEncoder

X = df_churn.drop('Churned', axis = 1)
y = df_churn['Churned']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=7175, stratify=y)


# # Закодируем страну как исторический отток, % людей которые уходят из страны.
# Не имеет эффекта, просто добавляет шум.
# encoder = TargetEncoder()
# X_train['Country_Encoded'] = encoder.fit_transform(X_train[['Country']], y_train).ravel()
# X_test['Country_Encoded'] = encoder.transform(X_test[['Country']]).ravel()


X_train.drop(columns=['Country'], inplace=True)
X_test.drop(columns=['Country'], inplace=True)

# %% [markdown]
# ### Cтандартизация данных

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Подготовили данные для более эффективного обучения модели.
# Привели признаки к единому масштабу. Стандартизированли!!!!

# %% [markdown]
# ### Модель Логистической регрессии

# %% [markdown]
# Проверим модель логистической регрессии, так как нам необходимо предсказать принадлежность к одному из классов

# %%
model_LR = LogisticRegression(max_iter=30000, solver='lbfgs')
model_LR.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=30000)

# %%
y_pred_test_LR = model_LR.predict(X_test)
y_pred_train_LR = model_LR.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
def print_stats(pred_test, pred_train):
    print(f"TEST:  Accuracy — {accuracy_score(y_test, pred_test)}")
    print(f"TRAIN: Accuracy — {accuracy_score(y_train, pred_train)}")
    print(f"TEST:  Precision — {precision_score(y_test, pred_test)}")
    print(f"TRAIN: Precision — {precision_score(y_train, pred_train)}")
    print(f"TEST:  Recall — {recall_score(y_test, pred_test)}")
    print(f"TRAIN: Recall — {recall_score(y_train, pred_train)}")
    print(f"TEST:  F1 — {f1_score(y_test, pred_test)}")
    print(f"TRAIN: F1 — {f1_score(y_train, pred_train)}")

print_stats(y_pred_test_LR, y_pred_train_LR)
# Out:
# TEST:  Accuracy — 0.7783621337340345
# TRAIN: Accuracy — 0.7795135084369033
# TEST:  Precision — 0.69258872651357
# TRAIN: Precision — 0.6938318401102688
# TEST:  Recall — 0.42834086507424146
# TRAIN: Recall — 0.4333369202625632
# TEST:  F1 — 0.5293179098524132
# TRAIN: F1 — 0.5334834735377889

# %% [markdown]
# Метрика Accuracy - доля верно угаданных ответов
# $$Accuracy = \dfrac{TP + TN}{TP + TN + FP + FN}$$

# %% [markdown]
# Метрика Precision — доля верно угаданных элементов положительного класса среди всех элементов, помеченных положительными. Данная метрика демонстрирует способность модели отличать класс от других классов.
#
# $$Precision = \frac{TP}{TP + FP}$$

# %% [markdown]
# Recall — доля верно помеченных объектов положительного класса среди всех объектов положительного класса. Данная метрика демонстрирует способность алгоритма обнаруживать данный класс вообще.
#
# $$Recall = \frac{TP}{TP + FN}$$

# %% [markdown]
# F1-score — это среднее гармоническое точности и полноты. Данная метрика одинаково и сбалансированно учитывает важность точности и полноты, а потому показывает более четкую картину работы нашего алгоритма.
#
# $$F_1 = 2 \cdot \frac{Precision \cdot Recall}{Precision + Recall}$$

# %% [markdown]
# Точность модели составила около 77%, однако полнота в 40% указывает на то, что модель выявляет лишь часть клиентов, склонных к оттоку. Значение F1-меры 0,50 говорит о среднем качестве классификации.

# %% [markdown]
# ### Модель КNN

# %% [markdown]
# Модель KNN определяет класс объекта на основе класов его ближайших соседей (21 - число соседей).

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(21)

model_knn.fit(X_train, y_train)

y_pred_train_KNN = model_knn.predict(X_train)
y_pred_test_KNN  = model_knn.predict(X_test)

# %% [markdown]
# Оценим модель для трех порогов классификации: 0.5, 0.3, 0.91

# %%
print_stats(y_pred_test_KNN, y_pred_train_KNN)
# Out:
# TEST:  Accuracy — 0.790007513148009
# TRAIN: Accuracy — 0.8045894249131265
# TEST:  Precision — 0.8150584795321637
# TRAIN: Precision — 0.8624376336421953
# TEST:  Recall — 0.35990961910910263
# TRAIN: Recall — 0.39061659313461744
# TEST:  F1 — 0.4993282579489476
# TRAIN: F1 — 0.5376981187972152

# %% [markdown]
# **При пороге 0.5**
# - Модель показала точность 79%, превысив результаты логистической регрессии.
# - Но полнота осталась низкой (36%), значительная часть клиентов с оттоком не была обнаружена.

# %%
p_test = model_knn.predict_proba(X_test)[:, 1]
p_train = model_knn.predict_proba(X_train)[:, 1]
thresh = 0.3
y_pred_test_KNN_higher_thresh = (p_test >= thresh).astype(int)
y_pred_train_KNN_higher_thresh = (p_train >= thresh).astype(int)
print_stats(y_pred_test_KNN_higher_thresh, y_pred_train_KNN_higher_thresh)
# Out:
# TEST:  Accuracy — 0.7992111194590533
# TRAIN: Accuracy — 0.831418464139248
# TEST:  Precision — 0.6542416452442159
# TRAIN: Precision — 0.7069038542990258
# TEST:  Recall — 0.657198192382182
# TRAIN: Recall — 0.718390186161627
# TEST:  F1 — 0.6557165861513687
# TRAIN: F1 — 0.7126007365106474

# %% [markdown]
# **При пороге 0.3**
# - Существенно увеличилась полнота (65%), сохранив при этом хорошую точность.
# - Значение F1-меры выросло до 0.66, что делает данный вариант наиболее сбалансированным и эффективным для выявления клиентов, склонных к оттоку у текущей модели.

# %%
p_test = model_knn.predict_proba(X_test)[:, 1]
p_train = model_knn.predict_proba(X_train)[:, 1]
thresh = 0.91
y_pred_test_KNN_higher_thresh = (p_test >= thresh).astype(int)
y_pred_train_KNN_higher_thresh = (p_train >= thresh).astype(int)
print_stats(y_pred_test_KNN_higher_thresh, y_pred_train_KNN_higher_thresh)
# Out:
# TEST:  Accuracy — 0.7123403456048084
# TRAIN: Accuracy — 0.7133644303916351
# TEST:  Precision — 0.972972972972973
# TRAIN: Precision — 1.0
# TEST:  Recall — 0.011620400258231117
# TRAIN: Recall — 0.01474227913483267
# TEST:  F1 — 0.022966507177033493
# TRAIN: F1 — 0.029056203605514315

# %% [markdown]
# **При пороге 0.91**
# - Модель стала крайне консервативной:
#   - точность выросла (97%), однако полнота сильно упала (1.2%).
#   - В результате модель практически перестала выявлять клиентов с оттоком и стала непригодной для решения поставленной задачи.

# %% [markdown]
# ### Модель дерева решений

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
model_dtree = DecisionTreeClassifier(max_depth=7, random_state=7175)
model_dtree.fit(X_train, y_train)

y_pred_train_dtree = model_dtree.predict(X_train)
y_pred_test_dtree  = model_dtree.predict(X_test)

# %%
print_stats(y_pred_test_dtree, y_pred_train_dtree)
# Out:
# TEST:  Accuracy — 0.8749060856498873
# TRAIN: Accuracy — 0.8965970635193939
# TEST:  Precision — 0.8501189532117367
# TRAIN: Precision — 0.8886581884246042
# TEST:  Recall — 0.6920593931568754
# TRAIN: Recall — 0.7368987409878404
# TEST:  F1 — 0.7629893238434163
# TRAIN: F1 — 0.8056944526148597

# %% [markdown]
# 87% уверенность, 31% людей пропуск.

# %% [markdown]
# **Порог 0.96**
# "Снайперская" модель,
# - очень высокая точность,
# - но "не видит" 63% людей которые уйдут.
# - Здесь можно будет использовать дорогостоящие методы методы воздействия:

# %%
p_test = model_dtree.predict_proba(X_test)[:, 1]
p_train = model_dtree.predict_proba(X_train)[:, 1]
thresh = 0.96
y_pred_test_dtree_higher_thresh = (p_test >= thresh).astype(int)
y_pred_train_dtree_higher_thresh = (p_train >= thresh).astype(int)
print_stats(y_pred_test_dtree_higher_thresh, y_pred_train_dtree_higher_thresh)
# Out:
# TEST:  Accuracy — 0.8179939894815927
# TRAIN: Accuracy — 0.8310427949785556
# TEST:  Precision — 0.9915254237288136
# TRAIN: Precision — 0.9987199180747568
# TEST:  Recall — 0.3776630083925113
# TRAIN: Recall — 0.41977832777359303
# TEST:  F1 — 0.5469845722300141
# TRAIN: F1 — 0.5911053867717251

# %% [markdown]
# **Порог 0.3** "Общая" модель, пропускает только 23% людей которые уйдут, но имеет точность только 77%. Здесь можно будет применять менее дорогостоящие методы воздействия:

# %%
p_test = model_dtree.predict_proba(X_test)[:, 1]
p_train = model_dtree.predict_proba(X_train)[:, 1]
thresh = 0.3
y_pred_test_dtree_higher_thresh = (p_test >= thresh).astype(int)
y_pred_train_dtree_higher_thresh = (p_train >= thresh).astype(int)
print_stats(y_pred_test_dtree_higher_thresh, y_pred_train_dtree_higher_thresh)
# Out:
# TEST:  Accuracy — 0.8672990232907588
# TRAIN: Accuracy — 0.8864539961806969
# TEST:  Precision — 0.7745193874226133
# TRAIN: Precision — 0.8071335646140503
# TEST:  Recall — 0.7672692059393157
# TRAIN: Recall — 0.8011406434951038
# TEST:  F1 — 0.7708772498783849
# TRAIN: F1 — 0.8041259383269428

# %% [markdown]
# ### Сравнение моделей
# Логистическая регрессия показала параметры хуже чем две другие модели. KNN модель дала результаты с которыми можно работать, но recall был слишком низким. Используя свой порог можно было получить результаты пригодные для бизнесс решений
# При стандартном порогек модель достигает precision 85%, recall 69% и f1 0.76
# А также для разных целей бизнес можно использовать "снайперскую" и "общую" модели
#
# Модель деревья решений показала самые лучшие результаты с очень хорошими показателями.
# В бизнесе нужно будет применять именно её. С помощью порога можно будет разделить методы вмешательства:
# - более дорогостоящие, при высокой уверенности модели и при оправдывающем это действие ltv клиента.
# - менее дорогостоящие, при менее высокой уверенности модели.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

mp_mtx_lr = confusion_matrix(y_test, y_pred_test_LR)
mp_mtx_knn = confusion_matrix(y_test, y_pred_test_KNN)
mp_mtx_dtree = confusion_matrix(y_test, y_pred_test_dtree)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
sns.heatmap(mp_mtx_lr, annot=True, fmt="d",
            xticklabels=df["Churned"].unique(),
            yticklabels=df["Churned"].unique(),
           ax=ax1)
ax1.set_title("Logistic Regression")
ax1.set_xlabel("Predicted value")
ax1.set_ylabel("Real value")

sns.heatmap(mp_mtx_knn, annot=True, fmt="d",
            xticklabels=df["Churned"].unique(),
            yticklabels=df["Churned"].unique(),
           ax=ax2)
ax2.set_title("KNN")
ax2.set_xlabel("Predicted value")
ax2.set_ylabel("Real value")

sns.heatmap(mp_mtx_dtree, annot=True, fmt="d",
            xticklabels=df["Churned"].unique(),
            yticklabels=df["Churned"].unique(),
           ax=ax3)
ax3.set_title("Decision Tree")
ax3.set_xlabel("Predicted value")
ax3.set_ylabel("Real value")
# Out:
# Text(978.81045751634, 0.5, 'Real value')

# %%
from sklearn.metrics import roc_curve, auc

p_test_lr = model_LR.predict_proba(X_test)[:, 1]
p_train_lr = model_LR.predict_proba(X_train)[:, 1]

p_test_knn = model_knn.predict_proba(X_test)[:, 1]
p_train_knn = model_knn.predict_proba(X_train)[:, 1]

p_test_dtree = model_dtree.predict_proba(X_test)[:, 1]
p_train_dtree = model_dtree.predict_proba(X_train)[:, 1]

fpr_lr, tpr_lr, _ = roc_curve(y_test, p_test_lr)
fpr_knn, tpr_knn, _ = roc_curve(y_test, p_test_knn)
fpr_dtree, tpr_dtree, _ = roc_curve(y_test, p_test_dtree)

plt.figure(figsize=(10, 7))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label="LogReg")
plt.plot(fpr_knn, tpr_knn, label="kNN")
plt.plot(fpr_dtree, tpr_dtree, label="DTree")
plt.title(f'ROC AUC = {round(auc(fpr_lr, tpr_lr),2)}|{round(auc(fpr_knn, tpr_knn), 2)}')
plt.ylabel("True Positive Rate", fontsize=20)
plt.xlabel("False Positive Rate", fontsize=20)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

importance = model_dtree.feature_importances_
features = [col for col in df_churn.columns if col not in ['Churned', 'Country']]
feature_importance = pd.DataFrame({
    'Feature': features,
    'Importance': importance
})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

print("Влияние признаков датасета на решения принимаемые деревом решений:")
print(feature_importance.to_string(index=False))

sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='viridis', hue='Importance')
plt.title('Влияние признаков (при глубине 7)')
plt.xlabel('Влияние признака')
plt.ylabel('Признаки')
plt.show()
# Out:
# Влияние признаков датасета на решения принимаемые деревом решений:
#                          Feature  Importance
#                   Lifetime_Value    0.341586
#            Cart_Abandonment_Rate    0.179204
#              Discount_Usage_Rate    0.141676
#           Customer_Service_Calls    0.108976
#                              Age    0.058922
#         Days_Since_Last_Purchase    0.057511
#                  Email_Open_Rate    0.049979
#                Pages_Per_Session    0.026891
#                   Wishlist_Items    0.013481
#                     Returns_Rate    0.007097
#                  Login_Frequency    0.003891
#                 Mobile_App_Usage    0.003371
#                   Make_Wishlists    0.002689
#                Lifetime_Per_Year    0.001598
#          Product_Reviews_Written    0.000970
#    Social_Media_Engagement_Score    0.000692
#                   Credit_Balance    0.000524
#                     User_Revenue    0.000496
# ...

# %% [markdown]
# ## Этап 3. Решение бизнес-задачи 2.

# %% [markdown]
# На основе этих данных определить ценность клиента для бизнеса, из них можно будет судить о необходимости удержания наиболее важных клиентовю, что поможет компании рационально распределять бюджет на маркетинг, скидки и персональные предложения
# - Каких клиентов особенно важно сохранить компании?
# - Сколько ценности такие клиенты способны приносить бизнесу?

# %%
# для удобства при работе
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#     age  gender country        city  membership_years  login_frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
# 3  56.0  Female     USA    New York               2.6             10.0
# 4  35.0    Male   India       Delhi               3.1             29.0
#
#    session_duration_avg  pages_per_session  cart_abandonment_rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
# 4                  51.4                8.4                   19.1
#
#    wishlist_items  ...  payment_method_diversity_1.0  \
# 0             3.0  ...                          True
# ...

# %% [markdown]
# В признаках, где строки принимают не более 10 значений.
# - Прием из семинара

# %%
df.select_dtypes(include = ['object']).columns
# Out:
# Index(['gender', 'country', 'city'], dtype='object')

# %%
df = df.dropna()

# %%
print(df['gender'].nunique())
df['gender'].value_counts()
# Out:
# 3
# gender
# Female    21460
# Male      20339
# Other       792
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# USA          14783
# UK            6439
# Canada        5064
# Germany       4213
# Australia     3493
# France        3416
# India         2995
# Japan         2188
# Name: count, dtype: int64

# %%
df['city'].unique()
# Out:
# array(['Marseille', 'Manchester', 'Vancouver', 'New York', 'Delhi',
#        'Tokyo', 'Berlin', 'Houston', 'Calgary', 'Glasgow', 'Munich',
#        'Phoenix', 'Paris', 'Ottawa', 'Bangalore', 'Yokohama',
#        'Los Angeles', 'Sydney', 'Nagoya', 'Frankfurt', 'Cologne', 'Nice',
#        'Chicago', 'Toulouse', 'Brisbane', 'Mumbai', 'Montreal',
#        'Melbourne', 'Lyon', 'Hyderabad', 'Chennai', 'Leeds', 'Birmingham',
#        'Hamburg', 'Toronto', 'London', 'Perth', 'Adelaide', 'Kyoto',
#        'Osaka'], dtype=object)

# %%
df = pd.get_dummies(
    df,
    columns=['gender', 'country'],
    drop_first=True
)

df.head()
# Out:
#     age        city  membership_years  login_frequency  session_duration_avg  \
# 0  43.0   Marseille               2.9             14.0                  27.4
# 1  36.0  Manchester               1.6             15.0                  42.7
# 2  45.0   Vancouver               2.9             10.0                  24.8
# 3  56.0    New York               2.6             10.0                  38.4
# 4  35.0       Delhi               3.1             29.0                  51.4
#
#    pages_per_session  cart_abandonment_rate  wishlist_items  total_purchases  \
# 0                6.0                   50.6             3.0              9.0
# 1               10.3                   37.7             1.0             19.5
# 2                1.6                   70.9             1.0              9.1
# 3               14.8                   41.7             9.0             15.0
# 4                8.4                   19.1             9.0             32.5
#
# ...

# %% [markdown]
# ### Распределение целевой переменной

# %%
df['lifetime_value'].unique()
# Out:
# array([ 953.33, 1067.47, 1289.75, ..., 2365.98, 1293.6 , 1072.61])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df['lifetime_value'].hist(bins=100)

plt.xlabel("lifetime_value")
plt.show()

# %% [markdown]
# Наш таргет - lifetime_value - выручка от клиента. Кажется что признаки, касающиеся lifetime_per_year, user_revenue с ним пересекаются по смыслу. Поэтому не буду их использовать в анализе

# %%
cols_to_drop = ["lifetime_value", "user_revenue", "lifetime_per_year", 'city']

def prepare_X_y(df:pd.DataFrame, drop_cols:list[str], target:str="lifetime_value"):
  y = df[target]
  X = df.drop(columns=drop_cols)

  bools = df.select_dtypes(include='bool').columns
  X[bools] = X[bools].astype(int)

  return X, y

# %% [markdown]
# Для улучшения результатов модели в дальнейшем будем эксперимаентировать со списком признаков для удаления и сравнивать метрики. Сразу подготовим для этого функцию , возвращающую матрицу объектов-признаков X и таргет y.

# %% [markdown]
# ### Разделение на тренировочную и тестовую выборки

# %%
X, y = prepare_X_y(df, cols_to_drop)

# %%
X.head()
# Out:
#     age  membership_years  login_frequency  session_duration_avg  \
# 0  43.0               2.9             14.0                  27.4
# 1  36.0               1.6             15.0                  42.7
# 2  45.0               2.9             10.0                  24.8
# 3  56.0               2.6             10.0                  38.4
# 4  35.0               3.1             29.0                  51.4
#
#    pages_per_session  cart_abandonment_rate  wishlist_items  total_purchases  \
# 0                6.0                   50.6             3.0              9.0
# 1               10.3                   37.7             1.0             19.5
# 2                1.6                   70.9             1.0              9.1
# 3               14.8                   41.7             9.0             15.0
# 4                8.4                   19.1             9.0             32.5
#
#    average_order_value  days_since_last_purchase  ...  monthly_income  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
import seaborn as sns
from copy import deepcopy

corr_plots = [
 "email_open_rate",
 "customer_service_calls",
 "product_reviews_written",
 "social_media_engagement_score"]

# из семинара
X_train_plot = deepcopy(X_train)
X_train_plot["lifetime_value"] = y_train

sns.pairplot(
    X_train_plot,
    x_vars=X_train[corr_plots],
    y_vars=["lifetime_value"],
)

# %% [markdown]
# ### Бейзлайн модели LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
def linear_regressor(X_train, y_train, X_test):

  lr = LinearRegression()
  lr.fit(X_train, y_train)

  y_pred = lr.predict(X_test)
  return y_pred

# %% [markdown]
# ### Бейзлайн модели KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
def knn_regressor(X_train, y_train, X_test, n_neighbors=3, p=1):

  knn = KNeighborsRegressor(n_neighbors = n_neighbors, p = p)
  knn.fit(X_train, y_train)

  y_pred = knn.predict(X_test)
  return y_pred

# %% [markdown]
# ### Функции подсчёта метрик

# %% [markdown]
# * Mean Squared Error (MSE): $\frac{1}{n}\sum\limits_i^n(\widetilde{y}_i - y_i)^2$
# * Mean Absolute Error (MAE): $\frac{1}{n}\sum\limits_i^n|\widetilde{y}_i - y_i|$
# * Max Error: $\max\limits_i |\widetilde{y}_i - y_i|$
#
# где $\widetilde{y}$ — предсказанное значение, $y$ — реальное значение.

# %% [markdown]
# Дополнительно используются более продвинутые способы измерять качество работы регрессии:
#
# * Coefficient of determination ($R^2$): $1 - \frac{\sigma_{\widetilde{y}}^2}{\sigma_y^2} \in (-∞, 1]$
# * Mean Absolute Percentage Error (MAPE): $100 \cdot \frac{1}{n}\sum\limits_i^n\left|\frac{y_i - \widetilde{y}_i}{y_i}\right| \in [0, +∞)$

# %% [markdown]
# Эти метрики указывают долю, поэтому помогают при оценке метрик "на глаз"

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error
from sklearn.metrics import r2_score, mean_absolute_percentage_error

# %%
def show_metrics(y_test, y_pred):

  print("MSE: ", mean_squared_error(y_test, y_pred))
  print("MAE: ", mean_absolute_error(y_test, y_pred))
  print("MAX_ERROR: ", max_error(y_test, y_pred))
  print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))

  print("R2: ", r2_score(y_test, y_pred))
  print("MAPE: ", mean_absolute_percentage_error(y_test, y_pred))

# %%
show_metrics(y_test, linear_regressor(X_train, y_train, X_test))
# Out:
# MSE:  404167.1506191067
# MAE:  440.1914423434152
# MAX_ERROR:  7969.824717755552
# RMSE:  635.7414180459747
# R2:  0.49929997861063613
# MAPE:  473952276454805.75

# %% [markdown]
# Чтож, метрики у knn лучше по MAE, RMSE, R2. Значит модель описывает ценность клиента методом ближайших соседей точнее чем линейной регрессией. По крайней мере, по текущему набору признаков.

# %% [markdown]
# Также видно что MAPE имеет несвойственное значение. Пожалуй, это может быть связано с числом маленьких чисел (и даже нулей) при анализе. Проверим это, попробуем посчитать теже метрики, "отбросив" нули.

# %% [markdown]
# Переработаем функцию вывода метрик в виде конструктора, где требуемые метрики подаются как аргументы.

# %%
metrics = ['MSE', 'MAE', 'MAX_ERROR', 'RMSE', 'R2', 'MAPE']

def show_metrics(y_test, y_pred, metrics: list[str], make_non_zero=False):
  if 'MSE' in metrics:
    print("MSE: ", mean_squared_error(y_test, y_pred))
  if 'MAE' in metrics:
    print("MAE: ", mean_absolute_error(y_test, y_pred))
  if 'MAX_ERROR' in metrics:
    print("MAX_ERROR: ", max_error(y_test, y_pred))
  if 'RMSE' in metrics:
    print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))
  if 'R2' in metrics:
    print("R2: ", r2_score(y_test, y_pred))
  if 'MAPE' in metrics:
    # используем метрику MAPE только при отсутсвии нулей
    if make_non_zero:
      mask = y_test != 0
      y_test = y_test[mask]
      y_pred = y_pred[mask]
      print("MAPE: ", mean_absolute_percentage_error(y_test, y_pred))

# %% [markdown]
# Датасет без нулей.

# %%
show_metrics(y_test, linear_regressor(X_train, y_train, X_test), metrics, True)
# Out:
# MSE:  404167.1506191067
# MAE:  440.1914423434152
# MAX_ERROR:  7969.824717755552
# RMSE:  635.7414180459747
# R2:  0.49929997861063613
# MAPE:  0.4105014413573643

# %% [markdown]
# С нулями.

# %%
show_metrics(y_test, linear_regressor(X_train, y_train, X_test), metrics)
# Out:
# MSE:  404167.1506191067
# MAE:  440.1914423434152
# MAX_ERROR:  7969.824717755552
# RMSE:  635.7414180459747
# R2:  0.49929997861063613

# %% [markdown]
# Для удобной работы с метриками и вычисления их разницы между разними методами добавим представление метрик в виде класса.

# %%
class Metrics():
  def __init__(self, y_test,
               y_pred,
               metrics=['MSE', 'MAE', 'MAX_ERROR', 'RMSE', 'R2', 'MAPE'],
               ) -> None:
    self.y_test = y_test
    self.y_pred = y_pred

    self.metrics = metrics
    #self.make_non_zero = make_non_zero

    #метрики
    self.MSE = None
    self.MAE = None
    self.MAX_ERROR = None
    self.RMSE = None
    self.R2 = None
    self.MAPE = None


  def get_metrics(self, make_non_zero=False):
    if 'MSE' in self.metrics:
      self.MSE = mean_squared_error(self.y_test, self.y_pred)
    if 'MAE' in self.metrics:
      self.MAE = mean_absolute_error(self.y_test, self.y_pred)
    if 'MAX_ERROR' in self.metrics:
      self.MAX_ERROR = max_error(self.y_test, self.y_pred)
    if 'RMSE' in self.metrics:
      self.RMSE = np.sqrt(mean_squared_error(self.y_test, self.y_pred))
    if 'R2' in self.metrics:
      self.R2 = r2_score(self.y_test, self.y_pred)
    if 'MAPE' in self.metrics:
      # используем метрику MAPE только при отсутсвии нулей
      if make_non_zero:
        mask = self.y_test != 0
        y_test_ = self.y_test[mask]
        y_pred_ = self.y_pred[mask][:len(y_test)]
        self.MAPE = mean_absolute_percentage_error(y_test_, y_pred_)

    return self

  def get_dict(self):
    # подготовит словарь для дальнейшего преобразования в DataFrame и опрятного вывода
    return {"MSE": self.MSE,
            "MAE": self.MAE,
            "MAX_ERROR": self.MAX_ERROR,
            "RMSE": self.RMSE,
            "R2": self.R2,
            "MAPE": self.MAPE}

  def __str__(self):
    return f" MSE: {self.MSE} \n MAE: {self.MAE} \n MAX_ERROR: {self.MAX_ERROR} \n RMSE: {self.RMSE} \n R2: {self.R2} \n MAPE: {self.MAPE}"

# %% [markdown]
# Проверка на реализованных моделях.

# %%
lr_metrics = Metrics(y_test=y_test, y_pred=linear_regressor(X_train, y_train, X_test)).get_metrics(True)
pd.DataFrame([lr_metrics.get_dict()], index=["Linear Regression"])
# Out:
#                              MSE         MAE    MAX_ERROR        RMSE      R2  \
# Linear Regression  404167.150619  440.191442  7969.824718  635.741418  0.4993
#
#                        MAPE
# Linear Regression  0.410501

# %%
knn_metrics = Metrics(y_test=y_test, y_pred=knn_regressor(X_train, y_train, X_test)).get_metrics(True)
pd.DataFrame([knn_metrics.get_dict()], index=["KNN"])
# Out:
#                MSE         MAE    MAX_ERROR        RMSE        R2      MAPE
# KNN  296392.994137  387.333106  3967.993333  544.419869  0.632815  0.361598

# %% [markdown]
# Сравнивать метрики разных моделей теперь гораздо удобнее.

# %% [markdown]
# ### Transformers-преобразования

# %% [markdown]
# Будем сравнивать на разных моделях с разными данными, полученными в результате использования StandartScaler и PCA. Поэтому определим несколько набором таких данных.

# %%
X_train.dtypes
# Out:
# age                                 float64
# membership_years                    float64
# login_frequency                     float64
# session_duration_avg                float64
# pages_per_session                   float64
# cart_abandonment_rate               float64
# wishlist_items                      float64
# total_purchases                     float64
# average_order_value                 float64
# days_since_last_purchase            float64
# discount_usage_rate                 float64
# returns_rate                        float64
# email_open_rate                     float64
# customer_service_calls              float64
# product_reviews_written             float64
# social_media_engagement_score       float64
# mobile_app_usage                    float64
# credit_balance                      float64
# churned                               int64
# social_media_engagement_missing       int64
# credit_balance_missing                int64
# ...

# %% [markdown]
# Такие типы имеют наши признаки. Сейчас важно разделить по сути бинарные признаки от численных перед применением Scaler. Это делается потому, что бинарные кодируют по сути Есть/Нет и "скалировать" их незачем.

# %%
def get_bin_cols(X_train):
  bin_cols = []
  # признаки значения которых бинарны
  for col in X_train.columns:
    contains = X_train[col].unique()
    if set(contains).issubset({0, 1}):
      bin_cols.append(col)
  return bin_cols

# %% [markdown]
# Тогда все остальные "пригодны" для Scaler

# %%
def get_num_cols(X_train):
  num_cols = []
  for col in X_train.columns:
    if col not in get_bin_cols(X_train):
      num_cols.append(col)
  return num_cols

# %%
num_cols = get_num_cols(X_train)
num_cols
# Out:
# ['age',
#  'membership_years',
#  'login_frequency',
#  'session_duration_avg',
#  'pages_per_session',
#  'cart_abandonment_rate',
#  'wishlist_items',
#  'total_purchases',
#  'average_order_value',
#  'days_since_last_purchase',
#  'discount_usage_rate',
#  'returns_rate',
#  'email_open_rate',
#  'customer_service_calls',
#  'product_reviews_written',
#  'social_media_engagement_score',
#  'mobile_app_usage',
#  'credit_balance',
#  'gender_code',
#  'monthly_income']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# 1. Базовый датасет без трансформаций
X_train_base = X_train.copy()
X_test_base = X_test.copy()

# 2. StandartScaler
scaler = StandardScaler()

X_train_scale = X_train.copy()
X_test_scale = X_test.copy()
# бинарные не скейлим
X_train_scale[num_cols] = scaler.fit_transform(X_train[num_cols])
# без fit для тестовой выборки
X_test_scale[num_cols] = scaler.transform(X_test[num_cols])

# %% [markdown]
# Имеем смесь бинарных признаков и зайскейленных численных.

# %%
X_train_scale.head()
# Out:
#             age  membership_years  login_frequency  session_duration_avg  \
# 15274  0.377611         -0.773537        -1.490068             -0.084569
# 38831 -0.156427          0.149973         0.680200              1.003399
# 20480 -1.135496          0.684636         1.063189              0.010867
# 4350  -1.758540         -0.579114        -1.490068             -0.084569
# 13162  0.199598          2.337232        -0.724091             -0.122743
#
#        pages_per_session  cart_abandonment_rate  wishlist_items  \
# 15274          -2.029157               1.525184       -1.350204
# 38831           1.298715              -0.485412        0.214467
# 20480          -0.337943              -0.356291        1.466204
# 4350           -1.265383               1.402212       -1.037270
# 13162          -0.938051               1.217754       -0.098467
#
#        total_purchases  average_order_value  days_since_last_purchase  ...  \
# ...

# %%
# 4. PCA без нормализации
pca = PCA(n_components=10)
pca.fit(X_train_base)

X_train_pca = pca.transform(X_train_base)
X_test_pca = pca.transform(X_test_base)


# 5. StandartScaler + PCA
# Создаем PCA и обучаем его на нормализованном трейне
pca = PCA(n_components=10)
pca.fit(X_train_scale)

# Применяем трансформации
X_train_scale_pca = pca.transform(X_train_scale)
X_test_scale_pca = pca.transform(X_test_scale)

# %% [markdown]
# ---

# %%
lr_metrics_scale = Metrics(y_test, linear_regressor(X_train_scale, y_train, X_test_scale)).get_metrics(True)

# %%
knn_metrics_scale = Metrics(y_test, knn_regressor(X_train_scale, y_train, X_test_scale)).get_metrics(True)

# %% [markdown]
# ---

# %%
lr_metrics_pca = Metrics(y_test, linear_regressor(X_train_pca, y_train, X_test_pca)).get_metrics(True)

# %%
lr_metrics_scale_pca = Metrics(y_test, linear_regressor(X_train_scale_pca, y_train, X_test_scale_pca)).get_metrics(True)

# %% [markdown]
# ---

# %%
knn_metrics_pca = Metrics(y_test, knn_regressor(X_train_pca, y_train, X_test_pca)).get_metrics(True)

# %%
knn_metrics_scale_pca = Metrics(y_test, knn_regressor(X_train_scale_pca, y_train, X_test_scale_pca)).get_metrics(True)

# %%
pivot_metrics = pd.DataFrame(
    [
        lr_metrics.get_dict(),
        knn_metrics.get_dict(),
        lr_metrics_scale.get_dict(),
        knn_metrics_scale.get_dict(),
        lr_metrics_pca.get_dict(),
        knn_metrics_pca.get_dict(),
        lr_metrics_scale_pca.get_dict(),
        knn_metrics_scale_pca.get_dict()
    ], index=['LinearRegression',
              'KNN',
              'LinearRegression + Scaler',
              'KNN + Scaler',
              'LinearRegression + PCA',
              'KNN + PCA',
              'LinearRegression + Scaler + PCA',
              'KNN + Scaler + PCA']
).sort_values('MAPE')

pivot_metrics
# Out:
#                                            MSE         MAE    MAX_ERROR  \
# KNN                              296392.994137  387.333106  3967.993333
# KNN + PCA                        329776.497954  412.728847  4881.543333
# LinearRegression                 404167.150619  440.191442  7969.824718
# LinearRegression + Scaler        404167.150619  440.191442  7969.824718
# LinearRegression + PCA           445495.227130  455.519645  8255.200589
# KNN + Scaler                     464145.601956  485.917376  5577.973333
# KNN + Scaler + PCA               470560.302773  496.590184  4712.926667
# LinearRegression + Scaler + PCA  481650.197914  494.107849  8082.666320
#
#                                        RMSE        R2      MAPE
# KNN                              544.419869  0.632815  0.361598
# KNN + PCA                        574.261698  0.591458  0.391489
# LinearRegression                 635.741418  0.499300  0.410501
# ...

# %% [markdown]
# На этоп этапе knn превосходит линейную регрессию по метрикам, но дальше мы попробуем другой метод

# %% [markdown]
# ### Промежуточный победитель по метрикам: KNN

# %% [markdown]
# Результаты экспериментов не впечатляют. Возможно, представленные методы не уместны для нелинейных зависимостей. Для улучшения метрик добавим еще один метод RandomForestRegressor.

# %% [markdown]
# Для него нужно написать свой бейзлайн, по уже установленному формату.

# %%
from sklearn.ensemble import RandomForestRegressor

def rfr_regressor(X_train, y_train, X_test):
  # Создадим объект класса RandomForestRegressor с параметрами по умолчанию
  #np.random.seed(13)
  #RFR = RandomForestRegressor(min_samples_split=2, max_features=6, max_depth=21)
  RFR = RandomForestRegressor(random_state=13)

  # Обучим его на обучающей части датасета при помощи метода fit
  RFR.fit(X_train, y_train)

  y_RFR_train_predict = RFR.predict(X_train)
  y_RFR_test_predict = RFR.predict(X_test)

  return y_RFR_test_predict

# %%
rfr_metrics = Metrics(y_test, rfr_regressor(X_train_base, y_train, X_test_base)).get_metrics(True)
print(rfr_metrics)
# Out:
#  MSE: 44379.45866781402
#  MAE: 150.05399649019836
#  MAX_ERROR: 2185.7178000000013
#  RMSE: 210.6643269939503
#  R2: 0.9450207769973763
#  MAPE: 0.10814566189120939

# %%
pivot_metrics = pd.DataFrame(
    [
        lr_metrics.get_dict(),
        knn_metrics.get_dict(),
        lr_metrics_scale.get_dict(),
        knn_metrics_scale.get_dict(),
        rfr_metrics.get_dict(),
        lr_metrics_pca.get_dict(),
        knn_metrics_pca.get_dict(),
        lr_metrics_scale_pca.get_dict(),
        knn_metrics_scale_pca.get_dict(),
    ], index=['Linear Regression', 'KNN', 'LinearRegression + Scaler',
              'KNN + Scaler', 'Random Forest', 'Linear Regression + PCA', 'KNN + PCA', 'Linear Regression + Scaler + PCA', 'KNN + Scaler + PCA']
)

pivot_metrics.sort_values('MAPE')
# Out:
#                                             MSE         MAE    MAX_ERROR  \
# Random Forest                      44379.458668  150.053996  2185.717800
# KNN                               296392.994137  387.333106  3967.993333
# KNN + PCA                         329776.497954  412.728847  4881.543333
# Linear Regression                 404167.150619  440.191442  7969.824718
# LinearRegression + Scaler         404167.150619  440.191442  7969.824718
# Linear Regression + PCA           445495.227130  455.519645  8255.200589
# KNN + Scaler                      464145.601956  485.917376  5577.973333
# KNN + Scaler + PCA                470560.302773  496.590184  4712.926667
# Linear Regression + Scaler + PCA  481650.197914  494.107849  8082.666320
#
#                                         RMSE        R2      MAPE
# Random Forest                     210.664327  0.945021  0.108146
# KNN                               544.419869  0.632815  0.361598
# ...

# %%
pivot_metrics[['MSE', 'MAE', 'MAX_ERROR', 'RMSE']].apply(lambda x: abs(np.log(x))).plot(kind='bar', figsize=(16, 6))
# Out:
# <Axes: >

# %%
pivot_metrics[['R2', 'MAPE']].plot(kind='bar', figsize=(16, 4))
# Out:
# <Axes: >

# %% [markdown]
# Случайный лес превосходит все ожидания.
# Результат действительно внушительный. Используем финальный тюнинг модели через подбор гиперпараметров с помощью RandomizedSearchCV и посмотрим повлияло ли это на метрики.

# %% [markdown]
# ### RandomizedSearchCV для автоподбора гиперпараметров

# %% [markdown]
# * Число деревьев в лесе (`n_estimators`) — этот параметр просто нужно выбрать достаточно большим.
# * Максимальное число признаков у дерева (`max_features`) — это самый важный параметр, его точно нужно подбирать.
# * Максимальная глубина деревьев (`max_depth`) — желательно не ограничивать, но это очень ресурсоемко, поэтому нужно подобрать достаточно глубокие, но все же органиченные деревья.
# * Минимальное число объектов в вершине для расщепления (`min_samples_split`) — тоже важный параметр, подбирается исходя из данных.

# %%
from sklearn.model_selection import RandomizedSearchCV

np.random.seed(13)
grid = RandomizedSearchCV(
            RandomForestRegressor(),                # Алгоритм, в котором будем подбирать параметры
            param_distributions = {                 # Сетка параметров в виде словаря
                'max_depth': range(6, 20),
                'min_samples_split': range(2, 9),
                'max_features': range(2, 11)
            },
            scoring = 'neg_mean_absolute_error',    # Какие метрики будут считаться
            cv = 6,                                 # CV для кросс-валидации (число фолдов или индексы)
            n_jobs = -1,                            # Число используемых ядер для работы
            return_train_score = True,              # Считать ли метрики на обучающей части
            n_iter=16,                              # Число итераций (сколько будем брать случайных наборов)
            verbose = 5,                            # Чем больше, тем алгоритм разговорчивее
        )

# Обучим сетку на обучающем датасете при помощи метода fit
grid.fit(X_train, y_train)
# Out:
# Fitting 6 folds for each of 16 candidates, totalling 96 fits
# RandomizedSearchCV(cv=6, estimator=RandomForestRegressor(), n_iter=16,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': range(6, 20),
#                                         'max_features': range(2, 11),
#                                         'min_samples_split': range(2, 9)},
#                    return_train_score=True, scoring='neg_mean_absolute_error',
#                    verbose=5)

# %%
print(f"Лучшая метрика:   {grid.best_score_}")
print(f"Лучшие параметры: {grid.best_params_}")
# Out:
# Лучшая метрика:   -196.3414766639257
# Лучшие параметры: {'min_samples_split': 4, 'max_features': 9, 'max_depth': 15}

# %% [markdown]
# От лучших гиперпараметров обучим затюненую модель случайного леса.

# %%
y_GS_train_predict = grid.best_estimator_.predict(X_train_base)
y_GS_test_predict = grid.best_estimator_.predict(X_test_base)

# %%
rfr_metrics_tuned = Metrics(y_test, y_GS_test_predict).get_metrics(True)

# %% [markdown]
# ### Сравнение моделей

# %%
pivot_metrics = pd.DataFrame(
    [
        lr_metrics.get_dict(),
        knn_metrics.get_dict(),
        lr_metrics_scale.get_dict(),
        knn_metrics_scale.get_dict(),
        rfr_metrics.get_dict(),
        rfr_metrics_tuned.get_dict(),
        lr_metrics_pca.get_dict(),
        knn_metrics_pca.get_dict(),
        lr_metrics_scale_pca.get_dict(),
        knn_metrics_scale_pca.get_dict(),
    ], index=['Linear Regression',
              'KNN',
              'LinearRegression + Scaler',
              'KNN + Scaler',
              'Random Forest',
              'Random Forest + Tune',
              'Linear Regression + PCA',
              'KNN + PCA',
              'Linear Regression + Scaler + PCA',
              'KNN + Scaler + PCA']
)

pivot_metrics.sort_values('MAPE')
# Out:
#                                             MSE         MAE    MAX_ERROR  \
# Random Forest                      44379.458668  150.053996  2185.717800
# Random Forest + Tune               77885.225996  192.496442  3122.180738
# KNN                               296392.994137  387.333106  3967.993333
# KNN + PCA                         329776.497954  412.728847  4881.543333
# Linear Regression                 404167.150619  440.191442  7969.824718
# LinearRegression + Scaler         404167.150619  440.191442  7969.824718
# Linear Regression + PCA           445495.227130  455.519645  8255.200589
# KNN + Scaler                      464145.601956  485.917376  5577.973333
# KNN + Scaler + PCA                470560.302773  496.590184  4712.926667
# Linear Regression + Scaler + PCA  481650.197914  494.107849  8082.666320
#
#                                         RMSE        R2      MAPE
# Random Forest                     210.664327  0.945021  0.108146
# ...

# %% [markdown]
# Вопреки ожиданиям, можем заметить, что подбор гиперпараметров не улучшил качество модели Random Forest. По этому лучшим вариантом для решения текущей бизнес задачи (предсказание LTV пользователя) является Randdom Forest со следующими показателями:

# %%
print(rfr_metrics)
# Out:
#  MSE: 44379.45866781402
#  MAE: 150.05399649019836
#  MAX_ERROR: 2185.7178000000013
#  RMSE: 210.6643269939503
#  R2: 0.9450207769973763
#  MAPE: 0.10814566189120939
